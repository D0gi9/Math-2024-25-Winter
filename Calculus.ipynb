# %% [markdown]
# <a href="https://colab.research.google.com/github/D0gi9/Math-2024-25-Winter/blob/main/Calculus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Calculus**

# %% [markdown]
# # **Functions**

# %% [markdown]
# Functions in mathematics are relations that map each input to exactly one output. They are often written as f(x), where "f" is the name of the function and "x" is the input variable. For each value of "x," the function produces a unique output, often called "f(x)" or "y." Functions can be represented in various forms, such as equations, graphs, or tables.
#
# Functions are widely used in algebra, calculus, and many other areas of mathematics. They can be classified into different types, including linear functions, quadratic functions, and exponential functions, based on the nature of their relationships. Functions are essential in describing how one quantity depends on another, making them fundamental in both mathematics and real-world applications.
#
# In calculus, a function plays a central role in understanding how quantities change. Calculus primarily focuses on two key concepts related to functions: derivatives and integrals.
#
# Derivatives: The derivative of a function measures the rate of change of the function's output with respect to its input. In simpler terms, it tells us how the value of a function is changing at any given point. The derivative is denoted as f'(x) or
# 𝑑
# 𝑓
# 𝑑
# 𝑥
# dx
# df
# ​
#  . For example, if a function represents the position of an object over time, its derivative gives the object's velocity (rate of change of position).
#
# Integrals: An integral represents the accumulation of quantities, such as finding the area under a curve. The integral of a function can be thought of as the reverse process of differentiation. It's denoted as
# ∫
# 𝑓
# (
# 𝑥
# )
# 𝑑
# 𝑥
#  and helps in calculating areas, volumes, and many other applications.
#
# Calculus explores the behavior of functions through limits, continuity, and the study of these two fundamental operations (derivatives and integrals) to understand real-world phenomena like motion, growth, and optimization.

# %% [markdown]
# # **EXAMPLES**

# %% [markdown]
# Draw in a single Geogebra notebook the following functions:
# f
# (
# x
# )
# =
# x
# 2

# %% [markdown]
# link to exercise:
#
#  https://www.geogebra.org/m/avjvcbke

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def f(x):
  return x**2

# Create x values
x = np.linspace(-10, 10, 400)

# Calculate corresponding y values
y = f(x)

# Plot the function
plt.plot(x, y)
plt.title("Graph of f(x) = x^2")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %%
import plotly.graph_objects as go
import numpy as np

# Define the function
def f(x):
  return x**2

# Create x values
x = np.linspace(-10, 10, 400)

# Calculate corresponding y values
y = f(x)

# Create the plot
fig = go.Figure(data=[go.Scatter(x=x, y=y)])
fig.update_layout(title="Graph of f(x) = x^2",
                  xaxis_title="x",
                  yaxis_title="f(x)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# g
# (
# x
# )
# =
# √x
#
# Geogebra link:
#
# https://www.geogebra.org/m/xnpmp4z2

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def g(x):
  return np.sqrt(x)

# Create x values (non-negative since we're taking the square root)
x = np.linspace(0, 10, 400)

# Calculate corresponding y values
y = g(x)

# Plot the function
plt.plot(x, y)
plt.title("Graph of g(x) = √x")
plt.xlabel("x")
plt.ylabel("g(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# h
# (
# x
# )
# =
# 1/x
#
# geogebra link:
#
# https://www.geogebra.org/m/scevtwt7

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def h(x):
  return 1/x

# Create x values (avoiding x=0 where the function is undefined)
x = np.linspace(-10, 10, 400)
x = x[x != 0]  # Remove x=0 to avoid division by zero

# Calculate corresponding y values
y = h(x)

# Plot the function
plt.plot(x, y)
plt.title("Graph of h(x) = 1/x")
plt.xlabel("x")
plt.ylabel("h(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# j
# (
# x
# )
# =
# sin
# ⁡
# (
# x
# )
#
# geogebra link:
#
# https://www.geogebra.org/m/s2f5kc2q

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def j(x):
  return np.sin(x)

# Create x values (using radians)
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)

# Calculate corresponding y values
y = j(x)

# Plot the function
plt.plot(x, y)
plt.title("Graph of j(x) = sin(x)")
plt.xlabel("x (radians)")
plt.ylabel("j(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# # **Find value of all the above functions at x=2**

# %% [markdown]
# Let
# f
# (
# x
# )
# =
# 3
# x
# −
# 1
#  and
# g
# (
# x
# )
# =
# √x Find:

# %% [markdown]
# 1) f
# (
# g
# (
# x
# )
# )
#
#
# f(g(x))=f(
# √x
# ​
#  )=3(
# √x
# ​
#  )−1
#
#
#  f(g(x))=3√x​−1
#
#
#  f(g(2))=3√2-1
#
#  √2≈1.414
#
#
#
#
# **the result is**
#
# (g(2))=3(1.414)−1=4.242−1=3.242

# %% [markdown]
# 2) g
# (
# f
# (
# x
# )
# )
#
#
# g(f(x))=g(3x−1)
#
#
# g(f(x))=√3x - 1
#
#
# g(f(2))=√(3(2) - 1)=√5
#
# **the result is**
#
# √5≈2.236

# %% [markdown]
# 3)f
# (
# f
# (
# x
# )
# )
#
# f(f(x))=f(3x−1)
#
# f(f(x))=f(5)
#
# f(x)=3x-1
#
# f(5)=15-1=14

# %% [markdown]
# 4)g
# (
# g
# (
# x
# )
# )
#
# g(g(x))=g(√x)
#
# g(g(x))=√√x
#
# g(g(x))=∜x
#
# g(g(2))= ∜2
#
# ∜2≈1.189
#
# the value of
# 𝑔
# (
# 𝑔
# (
# 2
# )
# )
# g(g(2)) is approximately 1.189.

# %% [markdown]
# visualize functions in a single Geogebra notebook.
#
# Let
# f
# (
# x
# )
# =
# eˣ
#  and
# g
# (
# x
# )
# =
# ln
# ⁡
# (
# x
# )
# . Check:
# f
# (
# g
# (
# x
# )
# )
#  and
# g
# (
# f
# (
# x
# )
# )
# . What do you notice?
#
#
# geogebra link:
#
# https://www.geogebra.org/m/nz2wp4ym

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the functions
def f(x):
  return np.exp(x)

def g(x):
  return np.log(x)  # np.log is the natural logarithm (ln)

# Create x values for f(g(x)) (x > 0 for ln(x) to be defined)
x_fg = np.linspace(0.1, 5, 400)

# Calculate f(g(x))
y_fg = f(g(x_fg))

# Create x values for g(f(x)) (all real numbers)
x_gf = np.linspace(-2, 2, 400)

# Calculate g(f(x))
y_gf = g(f(x_gf))

# Plot f(g(x))
plt.plot(x_fg, y_fg, label="f(g(x))")

# Plot g(f(x))
plt.plot(x_gf, y_gf, label="g(f(x))")

# Plot the line y = x for comparison (identity function)
plt.plot(x_fg, x_fg, linestyle="--", color="gray", label="y = x")

plt.title("Graphs of f(g(x)) and g(f(x))")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# We have function
# f
# =
# (
# 1
# ,
# 7
# )
# ,
# (
# 2
# ,
# 9
# )
# ,
# (
# 3
# ,
# 11
# )
# . Give inverse function f⁻¹
#
# geogebra link: https://www.geogebra.org/m/uvayhyct

# %%
import matplotlib.pyplot as plt

# Define the points for function f
x_f = [1, 2, 3]
y_f = [7, 9, 11]

# Define the points for the inverse function f⁻¹
x_finv = [7, 9, 11]
y_finv = [1, 2, 3]

# Plot function f
plt.scatter(x_f, y_f, color='blue', label='f(x)')

# Plot inverse function f⁻¹
plt.scatter(x_finv, y_finv, color='red', label='f⁻¹(x)')

# Plot the line y = x for comparison (reflection line)
plt.plot([0, 12], [0, 12], linestyle='--', color='gray', label='y = x')

plt.title('Graph of Function f and its Inverse f⁻¹')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# We have function
# f
# =
# (
# 1
# ,
# 7
# )
# ,
# (
# 2
# ,
# 7
# )
# ,
# (
# 3
# ,
# 11
# )
# . Give inverse function  f⁻¹

# %% [markdown]
# geogebra link:
#
# https://www.geogebra.org/m/uvayhyct

# %%
import matplotlib.pyplot as plt

# Define the points for function f
x_f = [1, 2, 3]
y_f = [7, 7, 11]

# Define the points for the potential inverse (swapping x and y)
x_finv = [7, 7, 11]
y_finv = [1, 2, 3]

# Plot function f
plt.scatter(x_f, y_f, color='blue', label='f(x)')

# Plot potential inverse
plt.scatter(x_finv, y_finv, color='red', label='Potential f⁻¹(x)')

# Plot the line y = x for comparison (reflection line)
plt.plot([0, 12], [0, 12], linestyle='--', color='gray', label='y = x')

plt.title('Graph of Function f and its Potential Inverse')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# We have function
# f
# (
# x
# )
# =
# x
# −
# 1
# . Give inverse function f⁻¹ Show both functions on the same Geogebra notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the functions
def f(x):
  return x - 1

def f_inverse(x):
  return x + 1

# Create x values
x = np.linspace(-5, 5, 400)

# Calculate y values for f(x) and f⁻¹(x)
y_f = f(x)
y_finv = f_inverse(x)

# Plot f(x)
plt.plot(x, y_f, label="f(x) = x - 1")

# Plot f⁻¹(x)
plt.plot(x, y_finv, label="f⁻¹(x) = x + 1")

# Plot the line y = x for comparison (reflection line)
plt.plot(x, x, linestyle="--", color="gray", label="y = x")

plt.title("Graph of f(x) and its Inverse")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()
