# %% [markdown]
# <a href="https://colab.research.google.com/github/D0gi9/Math-2024-25-Winter/blob/main/Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Functions
#
#
# **Definition:**
#
#
# $A$ function $f$ maps an input $x$ from its domain $D$ to an output $y$ in its range $R$:
#
#
# $y=f(x)$
#
#
# **Types of Functions:**
#
#
# **Linear Function:** $f(x)=mx+b$
#
#
# $m$: slope, $b$: y-intercept.
#
#
# **Quadratic Function:**
#
# $f(x)=ax^2+bx+c$
#
#
# **Exponential Function:**
#
# $f(x)=a⋅b^x$
#
#
# **Trigonometric Function:**
#
# $f(x)=sin(x),cos(x),tan(x)$
#
#
# Key Properties:
#
#
# Domain: Set of all possible inputs.
#
# Range: Set of all possible outputs.
#
# Increasing/Decreasing: Depends on the derivative , $f′(x)>0 or 𝑓′(𝑥)<0$
#
# Even/Odd Functions:
#
# $f(−x)=f(x) (even), f(−x)=−f(x) (odd).$
#
# Common Operations:
#
# $Composition: (f∘g)(x)=f(g(x))$
#
# Inverse: If $y=f(x)$, the inverse
# $𝑓^−1(𝑦) $satisfies  $𝑓(𝑓^−1(𝑦)) = y$

# %% [markdown]
# **Draw in a single Geogebra notebook the following functions:**
#
# 1)$f(x)=x^2$   , geogebra link:=https://www.geogebra.org/m/avjvcbke

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def f(x):
  return x**2

# Generate x values
x = np.linspace(-10, 10, 100)

# Calculate y values using the function
y = f(x)

# Create the plot
plt.plot(x, y)
plt.title("Graph of f(x) = x^2")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# 2)$g(x) = \sqrt{x}$  , Geogebra:https://www.geogebra.org/m/xnpmp4z2

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def g(x):
  return np.sqrt(x)

# Generate x values (starting from 0 to avoid errors with negative square roots)
x = np.linspace(0, 10, 100)

# Calculate y values using the function
y = g(x)

# Create the plot
plt.plot(x, y)
plt.title("Graph of g(x) = √x")
plt.xlabel("x")
plt.ylabel("g(x)")
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# 3)$h(x) = \frac{1}{x}$ ,  Geogebra:https://www.geogebra.org/m/scevtwt7

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def h(x):
  return 1/x

# Generate x values, avoiding x=0 where the function is undefined
x = np.linspace(-10, 10, 100)
x = x[x != 0]  # Remove x=0 to avoid division by zero

# Calculate y values using the function
y = h(x)

# Create the plot
plt.plot(x, y)
plt.title("Graph of h(x) = 1/x")
plt.xlabel("x")
plt.ylabel("h(x)")
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# 4)$j(x)=sin⁡(x)$  ,  Geogebra:https://www.geogebra.org/m/s2f5kc2q

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def j(x):
  return np.sin(x)

# Generate x values
x = np.linspace(-2 * np.pi, 2 * np.pi, 100)  # Using values from -2π to 2π

# Calculate y values using the function
y = j(x)

# Create the plot
plt.plot(x, y)
plt.title("Graph of j(x) = sin(x)")
plt.xlabel("x")
plt.ylabel("j(x)")
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# **Find value of all the above functions at $x=2$**
#
#
# Let $f(x)=3x-1$ and $g(x) = \sqrt{x}$ Find:
#
# 1)$f(g(x))$
#
# 2)$g(f(x))$
#
# 3)$f(f(x))$
#
# 4)$g(g(x))$

# %% [markdown]
# 1)$f(g(x))$
#
# **Step 1:** we need to find $g$ first and we will use that for finding it
#
# $g(x) = \sqrt{x}$
#
# if we put 2 instead of if we will get
#
# $g(2) = \sqrt{2}$
#
#
# now we will put that $\sqrt{2}$ to the $f(x)=3x-1$
#
# if we put $\sqrt{2}$ instead of $x$ if we will get
#
#
# $f(x)=3x-1$ = $f(\sqrt{2})=3.\sqrt{2}-1$
#
# Final Answer:
#
# $3\sqrt{2} - 1$

# %% [markdown]
# 2)$g(f(x))$
#
# **Step 1:** we need to find $f$ first and we will use that for finding it
#
# $f(x)=3x-1$
#
# if we put 2 instead of if we will get
#
# $f(2)=3.2-1 = 5$
#
#
# now we will put that 5 to the $g(x) = \sqrt{x}$
#
# if we put 5 instead of $x$ if we will get
#
# $g(5) = \sqrt{5}$
#
# Final Answer:
#
#
# $\sqrt{5}$

# %% [markdown]
# 3)$f(f(x))$
#
#
# **Step 1:** we need to find $f$ first and we will use that for finding it
#
# $f(x)=3x-1$
#
# if we put 2 instead of if we will get
#
# $f(2)=3.2-1 = 5$
#
#
# now we will put that 5 to the $f(x)=3x-1$
#
# if we put 5 instead of $x$ if we will get
#
# $f(5)=3.5-1 = 14$
#
# Final Answer:
#
#
# 14

# %% [markdown]
# 4)$g(g(x))$
#
#
# **Step 1:** we need to find $g$ first and we will use that for finding it
#
# $g(x) = \sqrt{x}$
#
# if we put 2 instead of if we will get
#
# $g(2) = \sqrt{2}$
#
#
# now we will put that $\sqrt{2}$ to the $g(x) = \sqrt{x}$
#
# if we put $\sqrt{2}$ instead of $x$ if we will get
#
#
# $g(\sqrt{2}) = \sqrt{\sqrt{2}}$
#
# Final Answer:
#
#
# $\sqrt{\sqrt{2}}$

# %% [markdown]
# and visualize functions in a single Geogebra notebook.
#
#
# Geogebra:https://www.geogebra.org/m/vv6akr78

# %% [markdown]
# Let $f(x)=e^x$ and $g(x)=ln⁡(x)$Check: $f(g(x))$ and $g(f(x))$ What do you notice?
#
#
# Find $f(g(x)):$
#
#
# Substitute $g(x)=ln(x)$ into $f(x)=e^x$:
#
#
# $f(g(x))=f(ln(x))  =e^ln(x)$
#
#
# $f(g(x))=x$
#
#
# Find $g(f(x))$:
#
#
# Substitute $f(x)=e^x$into $g(x)=ln(x)$:
#
# $g(f(x))=g(e^x)=ln(e^x)$
#
#
# Using the property of logarithms $ln(e^x)=x:$
#
#
# $g(f(x))=x$
#
#
# **What Do You Notice?**
#
#
# Both $f(g(x))$ and $g(f(x))$ result in $x$:
#
#
# $f(g(x))=g(f(x))=x$
#
# This means $f(x)=e^x$ and $g(x)=ln(x)$ are inverse functions of each other. Applying one function and then the other returns the original input. This relationship holds only when $x>0$ (since $g(x)=ln(x)$ is undefined for $x≤0$).

# %% [markdown]
# We have function $f=(1,7),(2,9),(3,11)$ Give inverse function $f^{-1}$
#
#
# Steps to Find $f^{-1}$
#
#
# Swap each $(x,y)$ pair to $(y,x)$:
#
#
# $f^{-1} = {(7,1),(9,2),(11,3)}$
#
#
# Final Answer:
#
#
# $f^{-1} = {(7,1),(9,2),(11,3)}$

# %% [markdown]
# We have function $f=(1,7),(2,7),(3,11)$ Give inverse function $f^{-1}$
#
#
# Step 1: Check if the Function is Invertible
#
#
# For a function to have an inverse, it must be one-to-one (injective), meaning no two different inputs $x_1$ and $x_2$ can produce the same output $y$ In this case:
#
#
# $f(1)=7$
#
# $f(2)=7$
#
# Since $1≠2$ but $f(1)=f(2)=7$ , the function is not one-to-one, and thus it does not have an inverse.
#
#
# **Conclusion**
#
#
# The function $f$ does not have an inverse because it is not injective.

# %% [markdown]
# We have function $f(x)=x−1$ Give inverse function $f^{-1}$  Show both functions on the same Geogebra notebook.
#
#
# Finding the Inverse Function $f^{-1}(x)$
#
#
# Replace $f(x)$ with $y$:
#
#
# $y=x−1$
#
#
# Swap $x$ and $y$
#
#
# Solve for $y$:
#
#
# $y=x+1$
#
#
# Thus, the inverse function is:
#
#
# $f^{-1}(x)$ = x+1$
#
#
# **Functions:**
#
#
# $f(x)=x−1$
#
#
# $f^{-1}(x)$ = x+1$
#
# Geogebra link: https://www.geogebra.org/calculator/e9g4psnx

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the functions
def f(x):
  return x - 1

def f_inverse(x):
  return x + 1

# Generate x values
x = np.linspace(-5, 5, 100)

# Calculate y values
y1 = f(x)
y2 = f_inverse(x)
y3 = x  # For the line y = x

# Create the plot
plt.figure(figsize=(8, 6))

plt.plot(x, y1, label="f(x) = x - 1")
plt.plot(x, y2, label="f⁻¹(x) = x + 1")
plt.plot(x, y3, label="y = x", linestyle="--")  # Dashed line for y = x

# Add labels, title, and legend
plt.xlabel("x")
plt.ylabel("y")
plt.title("Graphs of f(x), f⁻¹(x), and y = x")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
