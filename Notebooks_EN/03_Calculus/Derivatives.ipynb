# %% [markdown]
# <a href="https://colab.research.google.com/github/D0gi9/Math-2024-25-Winter/blob/main/Derivatives.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Derivatives
#
#
# **Power Rule:**
#
#
# $
# \text{If } y = x^n, \text{ then } \frac{dy}{dx} = nx^{n-1}$
#
#
# **Product Rule:**
#
#
# $
# \text{If } y = u(x)v(x), \text{ then }$
#
#  $\frac{dy}{dx} = u'(x)v(x) + u(x)v'(x)$
#
#
#  **Quotient Rule:**
#
#
# $
# \text{If } y = \frac{u(x)}{v(x)}, \text{ then }$
#
#
# $ \frac{dy}{dx} = \frac{u'(x)v(x) - u(x)v'(x)}{[v(x)]^2}$
#
#
# **Chain Rule:**
#
#
# $
# \text{If } y = f(g(x)), \text{ then } \frac{dy}{dx} = f'(g(x)) \cdot g'(x)$

# %% [markdown]
# # **Compute derivatives of functions:**

# %% [markdown]
# $1)y(x)=−3x+3$
#
# Using the power rule
# $\frac{d}{dx} [ax^n] = n \cdot a \cdot x^{n-1}$ the derivative is:
#
#
#
# $\frac{dy}{dx} = -3$

# %% [markdown]
# $2)y(x)=πx+sin(1)$
#
#
# The derivative of
# $πx$ is $π$, since $π$ is a constant.
#
# The derivative of sin(1) is 0, because sin(1) is a constant
#
#
# $\frac{dy}{dx} = π$

# %% [markdown]
# $3)y(x)=4+sin(2)$
#
# The derivative of the constant 4 is 0.
#
# The derivative of sin(2) is also 0, since sin(2) is a constant
#
# $\frac{dy}{dx} = 0 $

# %% [markdown]
# $4)y(x) = 2x^3 - 3x^2 + 8x - 9$
#
#
#
# The derivative of $2x^3$ is $6x^2$ (since $\frac{d}{dx}(x^n) = n \cdot x^{n-1}$, and here $n=3$)
#
#
# The derivative of $-3x^2$ is $-6x$ (since $\frac{d}{dx}(x^n) = n \cdot x^{n-1}$, and here $n=2$).
#
#
# The derivative of $8x$ is $8$ (since $\frac{d}{dx}(x) = 1$).
#
# The derivative of the constant −9 is 0.Thus, the derivative is:
#
#
#
# $\frac{dy}{dx} = 6x^2 - 6x + 8$

# %% [markdown]
# $5)y(x) = 6x^{1/3}$
#
#
# The derivative of $6x^{1/3}$ is:
#
#
# $\frac{d}{dx}(6x^{1/3}) = 6 \cdot \frac{1}{3} \cdot x^{1/3 - 1} = 2x^{-2/3}$
#
#
# Thus, the derivative is:
#
# $\frac{dy}{dx} = 2x^{-2/3}$
#
# Or equivalently:
#
# $\frac{dy}{dx} = \frac{2}{x^{2/3}}$

# %% [markdown]
# $6)y(x) = \sqrt{x}$
#
#
# $y(x) = \sqrt{x}$ = $x^{1/2}$
#
#
# Now, we apply the power rule for derivatives, which states:
#
# $\frac{d}{dx}(x^n) = n \cdot x^{n-1}$
#
#
# Here, $n = \frac{1}{2}$, so the derivative of $x^{1/2}$ is:
#
# $\frac{d}{dx}(x^{1/2}) = \frac{1}{2} \cdot x^{1/2 - 1} = \frac{1}{2} \cdot x^{-1/2}$
#
# Thus, the derivative is:
#
#
# $\frac{dy}{dx} = \frac{1}{2\sqrt{x}}$

# %% [markdown]
# $7)y(x)=cos(x)+sin(x)$
#
#
# $y(x)+x⋅y ′(x)$
#
#
#
# $\frac{d}{dx}(\cos(x) + \sin(x)) = -\sin(x) + \cos(x)$
#
# set up the equation after differentiating both sides:
#
# $y(x)+x⋅y ′(x)=−sin(x)+cos(x)
#
# $Solve for y ′(x):$
#
# $x⋅y ′(x)=−sin(x)+cos(x)−y(x)$
#
# $y ′(x)= x −sin(x)+cos(x)−y(x)$
#
#
# $thus, the derivative of y(x) is:$
#
#
# latex
# $y'(x) = \frac{- \sin(x) + \cos(x) - y(x)}{x}$

# %% [markdown]
# $8)y(x)=2sin(x)cos⁡(x)$
#
#
# Step 1: Apply the Product Rule
#
#
# $u′(x)v(x)+u(x)v′(x)$
#
# Here, $u(x)=sin(x)$ and $v(x)=cos(x)$ Thus:
#
#
# $y′(x)=2\frac{d}{dx} (\sin(x)) \cdot \cos(x) + \sin(x) \cdot \frac{d}{dx} (\cos(x))$
#
#
# **Step 2: Compute the Derivatives**
#
#
# $\frac{d}{dx} (\sin(x)) = \cos(x)$ , $\frac{d}{dx} (\cos(x)) = -\sin(x)$
#
#
# Substitute these into the equation:
#
#
# $y'(x) = 2[\cos(x) \cdot \cos(x) + \sin(x) \cdot (-\sin(x))]$
#
#
# Step 3: Simplify the Expression
#
#
# $y′(x)=2[cos^2(x)−sin^2(x)]$
#
#
# Step 4: Use the Trigonometric Identity
#
#
# $cos^2(x)−sin^2(x)=cos(2x)$
#
#
# Final Answer:
#
#
# $
# \frac{dy}{dx} = 2\cos(2x)$

# %% [markdown]
# $9)y(x)=xsin⁡(x)$
#
#
# Step 1: Recall the Product Rule
#
#
# $\frac{d}{dx} [u(x)v(x)] = u'(x)v(x) + u(x)v'(x)$
#
#
# Here:
#
# $u(x)=x$
#
# $v(x)=sin(x)$
#
#
# Step 2: Compute the Derivatives
#
#
# $u'(x) = \frac{d}{dx}(x) = 1$ , $v'(x) = \frac{d}{dx}(\sin(x)) = \cos(x)$
#
#
# Step 3: Apply the Product Rule
#
# $
# \frac{dy}{dx} = u'(x)v(x) + u(x)v'(x)
# $
#
#
# Substitute:
#
#
# $
# \frac{dy}{dx} = (1)(\sin(x)) + (x)(\cos(x))
# $
#
#
# Step 4: Simplify
#
#
# $
# \frac{dy}{dx} = \sin(x) + x\cos(x)
# $
#
#
# Final Answer:
#
# $\frac{dy}{dx} = \sin(x) + x\cos(x)$

# %% [markdown]
# $10)y(x)=(x+1)(x+1)$
#
#
# Step 1: Expand the Function
#
#
# $y(x)=(x+1)(x+1)=(x+1)^2$
#
#
# Step 2: Use the Chain Rule
#
#
# The derivative of (x+1)^2with respect to x is:
#
#
# $\frac{dy}{dx} = 2(x+1) \cdot \frac{d}{dx}(x+1)$
#
#
#
# $\text{Since } \frac{d}{dx}(x+1) = 1:$
#
#
# $
# \frac{dy}{dx} = 2(x+1)
# $
#
#
# **Final answer**
#
# $
# \frac{dy}{dx} = 2(x+1)
# $

# %% [markdown]
# $11)y(x) = \frac{x}{x+1}$
#
#
# Step 1: Recall the Quotient Rule
#
#
# The quotient rule states:
#
#
# $
# \frac{d}{dx} \left[ \frac{u(x)}{v(x)} \right] = \frac{u'(x)v(x) - u(x)v'(x)}{[v(x)]^2}$
#
# Here:
#
# $u(x)=x$
#
# $v(x)=x+1$
#
#
# Step 2: Compute the Derivatives
#
#
# $u'(x) = \frac{d}{dx}(x) = 1$ , $v'(x) = \frac{d}{dx}(x+1) = 1$
#
#
# Step 3: Apply the Quotient Rule
#
#
# $
# \frac{dy}{dx} = \frac{u'(x)v(x) - u(x)v'(x)}{[v(x)]^2}$
#
#
# Substitute
#
#
# $\frac{dy}{dx} = \frac{(1)(x+1) - (x)(1)}{(x+1)^2}$
#
#
# Step 4: Simplify
#
#
# $\frac{dy}{dx} = \frac{x+1-x}{(x+1)^2}$
#
#
#
# $\frac{dy}{dx} = \frac{1}{(x+1)^2}$
#
#
# Final Answer:
#
#
# $\frac{dy}{dx} = \frac{1}{(x+1)^2}$

# %% [markdown]
# $12)y(x)=(x+1)exp⁡(x)$
#
#
# Step 1: Recall the Product Rule
#
#
# The product rule states:
#
#
#
# $\frac{d}{dx} [u(x)v(x)] = u'(x)v(x) + u(x)v'(x)$
#
#
# Here:
#
#
# $u(x)=x+1$
#
#
# $v(x)=𝑒^x$
#
#
# Step 2: Compute the Derivatives
#
#
# $u'(x) = \frac{d}{dx}(x+1) = 1$ , $v'(x) = \frac{d}{dx}(e^x) = e^x$
#
#
# Step 3: Apply the Product Rule
#
#
# $\frac{dy}{dx} = u'(x)v(x) + u(x)v'(x)$
#
#
# Substitute:
#
#
# $\frac{dy}{dx} = (1)(e^x) + (x+1)(e^x)$
#
#
# Step 4: Simplify
#
# $\frac{dy}{dx} = e^x + (x+1)e^x = e^x(x+2)$
#
#
# Final Answer:
#
# $
# \frac{dy}{dx} = e^x(x+2)
# $

# %% [markdown]
# $13)y(x)=sin⁡(x^2)$
#
#
# Step 1: Recall the Chain Rule
#
#
# $\frac{d}{dx} f(g(x)) = f'(g(x)) \cdot g'(x)$
#
#
# Outer function: $f(u)=sin(u)$
#
# Inner function: $g(x)=x^2$
#
#
# Step 2: Compute the Derivatives
#
# The derivative of the outer function $f(u)=sin(u)$ is:
#
# $f′(u)=cos(u)$
#
#
# The derivative of the inner function g(x)=x^2 is:
#
# $g ′(x)=2x$
#
#
# Step 3: Apply the Chain Rule
#
#
# $
# \frac{dy}{dx} = \cos(x^2) \cdot \frac{d}{dx}(x^2)$
#
#
# Substitute
#
#
# $
# \frac{dy}{dx} = 2x\cos(x^2)$
#
# **Final answer**
#
#
# $
# \frac{dy}{dx} = 2x\cos(x^2)$

# %% [markdown]
# $14)y(x)=exp⁡(−2x)$
#
#
# Step 1: Recall the Chain Rule
#
# $
# \frac{d}{dx} f(g(x)) = f'(g(x)) \cdot g'(x)$
#
#
# Outer function: $f(u)=e^u$
#
# Inner function: $g(x)=−2x$
#
#
# Step 2: Compute the Derivatives
#
#
# The derivative of the outer function $f(u)=e^u$ is:
#
#
# $f′(u)=e^u$
#
#
# The derivative of the inner function $g(x)=−2x$ is:
#
# $g′(x)=−2$
#
#
# Step 3: Apply the Chain Rule
#
#
# $
# \frac{dy}{dx} = f'(g(x)) \cdot g'(x) = e^{-2x} \cdot (-2)$
#
#
# Step 4: Simplify
#
#
# $
# \frac{dy}{dx} = -2e^{-2x}$
#
# **Final answer**
#
# $
# \frac{dy}{dx} = -2e^{-2x}$

# %% [markdown]
# $15)y(x) = \frac{1}{\sin(x+1)}$
#
#
# Step 1: Rewrite the Function
#
#
# $
# y(x) = [\sin(x+1)]^{-1}$
#
#
# Step 2: Apply the Chain Rule
#
#
# The derivative of $[g(x)]^{-1}$ is:
#
#
# $\frac{d}{dx} [g(x)]^{-1} = -\frac{g'(x)}{[g(x)]^2}$
#
#
# Here:
#
# $g(x)=sin(x+1)$
#
#
# Step 3: Compute $g′(x)$
#
#
# $g'(x) = \frac{d}{dx}[\sin(x+1)] = \cos(x+1) \cdot \frac{d}{dx}(x+1) = \cos(x+1) \cdot 1 = \cos(x+1)
# $
#
#
# Step 4: Apply the Formula
#
#
# $
# \frac{dy}{dx} = -\frac{g'(x)}{[g(x)]^2}$
#
#
# Substitute
#
#
# $
# \frac{dy}{dx} = -\frac{\cos(x+1)}{[\sin(x+1)]^2}$
#
#
# Final Answer:
#
#
# $
# \frac{dy}{dx} = -\frac{\cos(x+1)}{[\sin(x+1)]^2}$

# %% [markdown]
# $16)y(x) = \sqrt{2x+1}$
#
#
# Step 1: Rewrite the Function
#
#
# $
# y(x) = (2x+1)^{\frac{1}{2}}$
#
#
# Step 2: Apply the Chain Rule
#
#
# The chain rule states:
#
#
# $
# \frac{d}{dx} [f(g(x))] = f'(g(x)) \cdot g'(x)$
#
#
# Here:
#
# Outer function: $f(u) = u^{\frac{1}{2}}$
#
#
# Inner function: $g(x)=2x+1$
#
#
# Derivative of the Outer Function
#
# $
# f'(u) = \frac{1}{2}u^{-\frac{1}{2}}$
#
#
# Derivative of the Inner Function
#
# $
# g'(x) = \frac{d}{dx}(2x+1) = 2$
#
#
# Step 3: Combine the Results
#
#
# $
# \frac{dy}{dx} = f'(g(x)) \cdot g'(x) = \frac{1}{2}(2x+1)^{-\frac{1}{2}} \cdot 2$
#
#
# Step 4: Simplify
#
# $
# \frac{dy}{dx} = \frac{2}{2}(2x+1)^{-\frac{1}{2}}$
#
#
# $
# \frac{dy}{dx} = (2x+1)^{-\frac{1}{2}}$
#
#
# Rewrite the negative exponent as a fraction:
#
#
# $
# \frac{dy}{dx} = \frac{1}{\sqrt{2x+1}}$
#
#
# Final Answer:
#
#
# $
# \frac{dy}{dx} = \frac{1}{\sqrt{2x+1}}$

# %% [markdown]
# $17)$Prove:$ \frac{d}{dx} (\ln(\sin(x))) = \cot(x) $
#
#
# Step 1: Recall the derivative of $ln⁡(𝑢)$
#
#
# The derivative of $ln(u)$ with respect to $𝑥$ is:
#
#
# $ \frac{d}{dx} (\ln(u)) = \frac{1}{u} \cdot \frac{du}{dx} $
#
#
# Here, $u=sin(x)$
#
#
# Step 2: Differentiate $ln(sin(x))$
#
#
# Let $f(x)=ln(sin(x))$ Using the chain rule:
#
#
# $ \frac{d}{dx} (\ln(\sin(x))) = \frac{1}{\sin(x)} \cdot \frac{d}{dx} (\sin(x)) $
#
#
# Step 3: Differentiate $sin(x)$
#
#
# The derivative of $sin(x)$ is $cos(x)$ Substituting this into the expression gives:
#
#
#
# $ \frac{d}{dx} (\ln(\sin(x))) = \frac{1}{\sin(x)} \cdot \cos(x) $
#
#
# Step 4: Simplify
#
#
# Using the trigonometric identity for $cot(x)$, where
#
#
#
# $ \cot(x) = \frac{\cos(x)}{\sin(x)} $
#
#
# we get:
#
#
#
# $ \frac{d}{dx} (\ln(\sin(x))) = \cot(x) $
#
#
# **Final answer**
#
#
# $ \frac{d}{dx} (\ln(\sin(x))) = \cot(x) $

# %% [markdown]
# $18)$For $f(x)=cos⁡(x)$, verify that l$ f''(x) = -f(x) $
#
#
# Step 1: Define $f(x)$
#
#
# $f(x)=cos(x)$
#
#
# Step 2: Find the first derivative $f′(x)$
#
#
# Using the derivative rule for $cos(x)$
#
#
# $f′(x)=−sin(x)$
#
#
# Step 3: Find the second derivative $f′′(x)$
#
#
# The derivative of $f′(x)=−sin(x)$ is:
#
#
# $f′′(x)=−cos(x)$
#
#
# Step 4: Compare $f′′(x)$ with $−f(x)$
#
#
# From Step 3, $f′′(x)=−cos(x)$, and from Step 1, $f(x)=cos(x)$ Therefore:
#
#
# $f′′(x)=−f(x)$
#
#
# **Final answer**
#
#
# The relationship $f′′(x)=−f(x)$ is verified for $f(x)=cos(x)$

# %% [markdown]
# 19)Using de l'Hospital's Rule, find the improper limits:
#
#
# A)$ \lim_{x \to 0} \frac{\sin(x)}{x} $
#
#
# Step 1: Check the indeterminate form
#
# As $x→0$:
#
#
# $sin(x)→0$ and $x→0$
#
#
# Thus:
#
#
# $ \lim_{x \to 0} \frac{\sin(x)}{x} = \frac{0}{0} \text{ (indeterminate form)} $
#
#
# an indeterminate form. Therefore, L'Hôpital's Rule applies.
#
# Step 2: Differentiate the numerator and denominator
#
#
#
# $ \lim_{x \to 0} \frac{\sin(x)}{x} = \lim_{x \to 0} \frac{1}{\cos(x)} $
#
#
# Step 3: Simplify and evaluate the new limit
#
#
#
# $ \frac{\cos(x)}{1} = cos(x) $
#
#
# As $x→0$ , $cos(0)=1$ Thus:
#
#
#
# $ \lim_{x \to 0} \frac{\sin(x)}{x} = 1 $
#
#
# Final Answer:
#
# $1$

# %% [markdown]
# B)$ \lim_{x \to \infty} \frac{\ln(x)}{x} $
#
# Step 1: Verify the indeterminate form
#
#
# As $x→∞:$
#
#
# $ln(x)→∞ $ and $x→∞$
#
# Thus:
#
#
# $ \lim_{x \to \infty} \frac{\ln(x)}{x} = \frac{\infty}{\infty}  \text{ (indeterminate form)} $
#
#
# Step 2: Differentiate the numerator and denominator
#
#
#
# $ \lim_{x \to \infty} \frac{\ln(x)}{x} = \lim_{x \to \infty} \frac{\frac{1}{x}}{1} $
#
#
# Step 3: Simplify the expression
#
#
#
# $ \frac{1}{\frac{1}{x}} = x $
#
#
# Step 4: Evaluate the new limit
#
#
# As $x→∞$ , $ \lim_{x \to \infty} \frac{1}{x} = 0 $ ,  Thus:
#
#
#
# $ \lim_{x \to \infty} \frac{\ln(x)}{x} = 0 $
#
#
# **Final Answer:**
#
# $0$

# %% [markdown]
# C)$ \lim_{x \to \infty} \frac{e^x}{x} $
#
#
# Step 1: Check the form of the limit
#
#
# As $x→∞:$
#
#
# $e^x→∞$ and $x→∞$
#
#
# Thus:
#
# $ \lim_{x \to \infty} \frac{e^x}{x} = \frac{\infty}{\infty}  \text{ (indeterminate form)} $
#
#
#
# Step 2: Differentiate the numerator and denominator
#
#
# The derivative of $𝑒^𝑥$is 𝑒$^𝑥$, and the derivative of $x$ is 1. Applying L'Hôpital's Rule:
#
#
#
# $ \lim_{x \to \infty} \frac{e^x}{x} = \lim_{x \to \infty} \frac{e^x}{1} $
#
#
# Step 3: Simplify the expression
#
#
#
#
# $ \frac{e^x}{1} = {e^x}$
#
#
# Step 4: Evaluate the new limit
#
#
# As $x→∞$ , $𝑒^𝑥→∞$ Therefore:
#
#
# $ \lim_{x \to \infty} \frac{e^x}{x} = \infty $
#
#
# **Final Answer:**
#
# $\infty $

# %% [markdown]
# $20)$In physics, the position of a particle is given by $ x(t) = 3t^2 - 6t + 1 $ Find the velocity $ V(t) = x'(t) $ and acceleration $ a(t) = V'(t) = x''(t) $ of the particle at time $t=2$
#
# Step 1: Find the velocity $V(t)$
#
#
# The velocity is the first derivative of the position function:
#
#
# $ V(t) = \frac{dx}{dt} = \frac{d}{dt} (3t^2 - 6t + 1) $
#
#
# Differentiate term by term:
#
#
# $V(t)=6t−6$
#
#
# Step 2: Find the acceleration $a(t)$
#
#
# The acceleration is the first derivative of the velocity function or the second derivative of the position function:
#
#
# $ a(t) = \frac{dV}{dt} = \frac{d^2x}{dt^2} $
#
#
# Differentiate $V(t)=6t−6$:
#
#
# $a(t)=6$
#
#
# Step 3: Evaluate $V(t)$ and $a(t)$ at $t=2$
#
#
# Velocity:
#
#
# $V(2)=6(2)−6=12−6=6$
#
#
# Acceleration:
#
# $a(2)=6$
#
#
# Final Answers:
#
#
# Velocity at $t=2:6$
#
#
# $Acceleration at t=2: 6$
