# %% [markdown]
# <a href="https://colab.research.google.com/github/D0gi9/Math-2024-25-Winter/blob/main/Equations_of_planes_in_space.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Equations of planes in space
#
# **1. General Form**
#
# The general equation of a plane is:
#
# $ax+by+cz+d=0,$
#
#
# **2. Point-Normal Form**
#
#
# $a(x-x_1) + b(y-y_1) + c(z-z_1) = 0$
#
#
# **3. Using Three Points**
#
#
# Find two vectors on the plane
#
#
# $\vec{AB} = \langle x_2 - x_1, y_2 - y_1, z_2 - z_1 \rangle$ ,
# $\vec{AC} = \langle x_3 - x_1, y_3 - y_1, z_3 - z_1 \rangle$
#
#
# Compute the normal vector as the cross product:
#
#
# $\vec{n} = \vec{AB} \times \vec{AC}$
#
# **Intercept Form**
#
#
# f the plane intercepts the $x-$ , $y-$, and z-axes at $a$, $b$, and $c$ respectively, the equation is:
#
#
# 1)The plane passes through points $A(1,2,3)$ , $B(3,4,5)$ and $C(2,1,4)$ Find the equation of the plane.
#
#
#
# Step 1: Equation of a plane
#
#
# $a(x-x_1) + b(y-y_1) + c(z-z_1) = 0$
#
#
# Step 2: Find two vectors on the plane
#
#
# $\vec{AB} = \langle 3-1, 4-2, 5-3 \rangle = \langle 2, 2, 2 \rangle$
#
#
# $\vec{AC} = \langle 2-1, 1-2, 4-3 \rangle = \langle 1, -1, 1 \rangle$
#
#
# Step 3: Find the normal vector
#
#
# The normal vector $n=⟨a,b,c⟩$ is perpendicular to both $AB$ and $AC We can find $n$by taking the cross product:
#
#
# $\vec{n} = \vec{AB} \times \vec{AC}$
#
#
# Using the determinant formula for the cross product:
#
#
# $\vec{n} = \begin{vmatrix} \mathbf{i} & \mathbf{j} & \mathbf{k} \\ 2 & 2 & 2 \\ 1 & -1 & 1 \end{vmatrix}$
#
#
#
# expand the determinant:
#
# $
# \vec{n} = \mathbf{i} \begin{vmatrix} 2 & 2 \\ -1 & 1 \end{vmatrix} - \mathbf{j} \begin{vmatrix} 2 & 2 \\ 1 & 1 \end{vmatrix} + \mathbf{k} \begin{vmatrix} 2 & 2 \\ 1 & -1 \end{vmatrix}$
#
#
# Simplify each minor:
#
#
# $\begin{vmatrix} 2 & 2 \\ -1 & 1 \end{vmatrix} = (2)(1) - (2)(-1) = 2 + 2 = 4$
#
#
# $
# \begin{vmatrix} 2 & 2 \\ 1 & 1 \end{vmatrix} = (2)(1) - (2)(1) = 2 - 2 = 0$
#
#
# $
# \begin{vmatrix} 2 & 2 \\ 1 & -1 \end{vmatrix} = (2)(-1) - (2)(1) = -2 - 2 = -4$
#
#
# Thus:
#
#
# $n=4i−0j−4k=⟨4,0,−4⟩$
#
# Step 4: Write the plane equation
#
#
# $4(x−1)+0(y−2)−4(z−3)=0$
#
#
# Simplify:
#
#
# $4x−4z+8=0$
#
#
# Divide through by 4:
#
#
# $x−z+2=0$
#
#
# Final Answer:
#
#
# $x−z+2=0$

# %% [markdown]
# 2)The plane passes through point
# $A
# (
# 1
# ,
# 2
# ,
# 3
# )$
#  and is parallel to the plane
# $2
# x
# +
# 3
# y
# +
# 4
# z
# =
# 5$ Find the equation of the plane.
#
#
# Step 1: Equation of a plane parallel to another plane
#
#
# If two planes are parallel, their normal vectors are the same. The given plane $2x+3y+4z=5$ has a normal vector $n=⟨2,3,4⟩$
#
#
# Therefore, the required plane has the general form:
#
#
# $2x+3y+4z+d=0$
#
#
# where $d$ is a constant to be determined.
#
#
# Step 2: Use the given point to find $d$
#
#
# Substitute $A(1,2,3)$ into the plane equation $2x+3y+4z+d=0$
#
#
#
# $2(1)+3(2)+4(3)+d=0$
#
#
# $2+6+12+d=0$
#
#
# $d=−20$
#
# Step 3: Write the final equation
#
#
# Substitute $d=−20$ into the plane equation:
#
#
# $2x+3y+4z−20=0$
#
#
# Final Answer:
#
#
# $2x+3y+4z−20=0$

# %% [markdown]
# 3)The plane passes through point $A(1,2,3)$ and is perpendicular to the normal vector $n=[2,3,4]$ Find the equation of the plane.
#
#
# Step 1: Point-Normal Form
#
#
# $a(x-x_1) + b(y-y_1) + c(z-z_1) = 0$
#
#
# Here:
#
# $(x_1,y_1,z_1) = (1,2,3)$
#
#
# $[a,b,c]=[2,3,4]$
#
#
# Step 2: Substitute into the equation
#
#
# Substitute $a=2$, $b=3$ , $c=4$ , and $(x_1,y_1,z_1) = (1,2,3)$
#
#
# $2(x−1)+3(y−2)+4(z−3)=0$
#
#
# Step 3: Simplify the equation
#
#
# Expand:
#
#
# $2x−2+3y−6+4z−12=0,$
#
#
# $2x+3y+4z−20=0$
#
#
# Final Answer:
#
#
# $2x+3y+4z−20=0$

# %% [markdown]
# 4)We have two planes $2x+3y+4z=5$ and $3x+4y+2z=6$ Find the line of intersection of these planes.
#
#
# Step 1: General Form of Planes
#
#
# $2x+3y+4z=5,$
#
#
# $3x+4y+2z=6.$
#
#
# A line of intersection lies in both planes, so any point on the line satisfies both equations
#
#
# Step 2: Find a Direction Vector for the Line
#
#
# The direction vector $d$ of the line is perpendicular to the normal vectors of both planes. The normal vectors of the planes are:
#
#
# $n_1=⟨2,3,4⟩$
#
#
# $n_2=⟨3,4,2⟩$
#
#
# The direction vector is given by the cross product:
#
#
# $\vec{d} = \vec{n_1} \times \vec{n_2}$
#
#
# Using the determinant formula:
#
#
# $\vec{d} = \begin{vmatrix} \mathbf{i} & \mathbf{j} & \mathbf{k} \\ 2 & 3 & 4 \\ 3 & 4 & 2 \end{vmatrix}$
#
#
# Expand the determinant:
#
#
# $\vec{d} = \mathbf{i} \begin{vmatrix} 3 & 4 \\ 4 & 2 \end{vmatrix} - \mathbf{j} \begin{vmatrix} 2 & 4 \\ 3 & 2 \end{vmatrix} + \mathbf{k} \begin{vmatrix} 2 & 3 \\ 3 & 4 \end{vmatrix}$
#
#
# Compute the minors:
#
#
# $\begin{vmatrix} 3 & 4 \\ 4 & 2 \end{vmatrix} = (3)(2) - (4)(4) = 6 - 16 = -10$
#
#
# $
# \begin{vmatrix} 2 & 4 \\ 3 & 2 \end{vmatrix} = (2)(2) - (4)(3) = 4 - 12 = -8$
#
#
#
# $\begin{vmatrix} 2 & 3 \\ 3 & 4 \end{vmatrix} = (2)(4) - (3)(3) = 8 - 9 = -1$
#
#
# Thus:
#
#
# $d=−10i−(−8)j−1k=⟨−10,8,−1⟩$
#
#
# The direction vector is:
#
#
# $d=⟨−10,8,−1⟩$
#
#
# Step 3: Find a Point on the Line
#
#
# To find a specific point on the line, solve the plane equations simultaneously. Choose $z=0$ (a parameter value for simplicity) and solve:
#
#
# $2x+3y=5$
#
# $3x+4y=6$
#
#
# Solve this system of linear equations: Multiply the first equation by 3 and the second by 2:
#
#
# $6x+9y=15 , 6x+8y=12$
#
#
# Subtract the second equation from the first:
#
#
# $y=3$
#
#
# Substitute $y=3$ into $2x+3y=5$
#
#
# $2x+3(3)=5$
#
#
# $2x+9=5$
#
#
# $2x=−4 \implies x = -2$
#
#
# When z=0, the point is:
#
#
# $(−2,3,0)$
#
#
# Step 4: Parametric Equation of the Line
#
#
# The line of intersection has the parametric form:
#
#
# $x=−2−10t,y=3+8t,z=−t,$
#
#
# Final Answer:
#
# The parametric equation of the line is:
#
#
# $x=-2-10t , y=3+8t , z = -t$

# %% [markdown]
# 5)Write the equation of the plane passing through point
# $A
# (
# 1
# ,
# 2
# ,
# 3
# )$
#  and parallel to vectors
# $v
# 1^
# →
# =
# [
# 1
# ,
# 0
# ,
# 1
# ]$
#  and
# $v
# 2^
# →
# =
# [
# 0
# ,
# 1
# ,
# −
# 1
# ]$
#
#
# Step 1: Equation of the Plane
#
#
# The equation of a plane is given by:
#
#
# $a(x-x_1) + b(y-y_1) + c(z-z_1) = 0$
#
#
# Step 2: Find the Normal Vector
#
#
# The normal vector $n$of the plane is perpendicular to both $\vec{v_1} \quad \text{and} \quad \vec{v_2}$ This can be found using the cross product:
#
#
# $\vec{n} = \vec{v_1} \times \vec{v_2}$
#
#
# Using the determinant formula for the cross product:
#
#
# $\vec{n} = \begin{vmatrix} \mathbf{i} & \mathbf{j} & \mathbf{k} \\ 1 & 0 & 1 \\ 0 & 1 & -1 \end{vmatrix}$
#
#
# Expand the determinant:
#
#
# $\vec{n} = \mathbf{i} \begin{vmatrix} 0 & 1 \\ 1 & -1 \end{vmatrix} - \mathbf{j} \begin{vmatrix} 1 & 1 \\ 0 & -1 \end{vmatrix} + \mathbf{k} \begin{vmatrix} 1 & 0 \\ 0 & 1 \end{vmatrix}$
#
#
# Simplify each minor:
#
#
# $
# \begin{vmatrix} 0 & 1 \\ 1 & -1 \end{vmatrix} = (0)(-1) - (1)(1) = 0 - 1 = -1
# $
#
#
# $\begin{vmatrix} 1 & 1 \\ 0 & -1 \end{vmatrix} = (1)(-1) - (1)(0) = -1 - 0 = -1$
#
#
# $\begin{vmatrix} 1 & 0 \\ 0 & 1 \end{vmatrix} = (1)(1) - (0)(0) = 1 - 0 = 1$
#
#
# Thus:
#
#
# $\vec{n}=−1i−(−1)j+1k=⟨−1,1,1⟩$
#
#
# The normal vector is:
#
#
# $\vec{n} = ⟨−1,1,1⟩$
#
#
# Step 3: Write the Equation of the Plane
#
#
# Using the point $A(1,2,3)$ and the normal vector $n=⟨−1,1,1⟩$, the equation of the plane is:
#
#
# $−1(x−1)+1(y−2)+1(z−3)=0$
#
#
# Simplify:
#
#
# $−x+1+y−2+z−3=0$
#
#
# $−x+y+z−4=0$
#
#
# Final Answer:
#
#
# $-x+y+z-4=0$

# %% [markdown]
# 6)We have the plane $2x+3y+4z=5$Find an example of a plane parallel and perpendicular to it.
#
#
# **Parallel Plane**
#
#
# A plane parallel to $2x+3y+4z=5$ will have the same normal vector $n=⟨2,3,4⟩$ The general equation of such a plane is:
#
#
# $2x+3y+4z=d$
#
#
# where $d$ is any constant other than 5 (to ensure it is not the same plane).
#
#
# Example:
#
#
# Take $d=10$ Then the equation of a parallel plane is:
#
#
# $2x+3y+4z=10$
#
#
# Perpendicular Plane:
#
#
# A plane perpendicular to $2x+3y+4z=5$ will have a normal vector orthogonal to $n=⟨2,3,4⟩$ To find such a normal vector, choose any vector $\vec{n} = \langle a, b, c \rangle$ satisfying:
#
#
# $2a+3b+4c=0$
#
#
# Example:
#
# Let
#
# $a=3$ and $b=−2$ Solve for $c$:
#
#
# $2(3)+3(−2)+4c=0$
#
# $6−6+4c=0$
#
#
# $4c = 0 \implies c = 0$
#
#
# Thus, $\vec{n_{\perp}} = \langle 3, -2, 0 \rangle$
#
#
# The equation of a perpendicular plane passing through the origin is:
#
# $3x−2y=0$
#
# Final Answer:
#
# A parallel plane: $2x+3y+4z=10$
#
#
# A perpendicular plane: $3x−2y=0$

# %% [markdown]
# 7)We have the plane
# $2
# x
# +
# 3
# y
# +
# 4
# z
# =
# 5$
#  and point
# $A
# (
# 1
# ,
# 2
# ,
# 3
# )$
#  Find the distance from point
# $A$
#  to this plane.
#
#
#  To calculate the distance from a point we use the formula
#
#
# $
# \text{Distance} = \frac{|ax_1 + by_1 + cz_1 + d|}{\sqrt{a^2 + b^2 + c^2}}$
#
#
# Step 1: Substitute into the Formula
#
#
# $∣ax_1
# ​
#  +by_1
# ​
#  +cz_1
# ​
#  +d∣=∣2(1)+3(2)+4(3)−5∣$
#
#
# Simplify:
#
#
# $∣2+6+12−5∣=∣15∣$
#
#
# For the denominator:
#
# $
# \sqrt{a^2 + b^2 + c^2} = \sqrt{2^2 + 3^2 + 4^2}
# = \sqrt{29}$
#
#
# Step 2: Compute the Distance
#
#
# Distance $=
# \frac{15}{\sqrt{29}}$
#
#
# Final Answer:
#
#
#  $=
# \frac{15}{\sqrt{29}}$

# %% [markdown]
# 8)The plane intersects the coordinate axes at points
# $A
# (
# 2
# ,
# 0
# ,
# 0
# )
# ,
# B
# (
# 0
# ,
# 3
# ,
# 0
# )$
# , and
# $C
# (
# 0
# ,
# 0
# ,
# 4
# )$
#  Find the equation of the plane.
#
#
#
# General Form of a Plane
#
#
# $ax+by+cz=d$
#
#
# where $a,b,c$ are constants, and the plane passes through points $A,B,C$
#
#
# Step 2: Substitute Points into the Equation
#
#
# The plane passes through:
#
#
# $A(2,0,0)$: Substituting into $ax+by+cz=d$
#
#
# $a(2)+b(0)+c(0)=d⟹2a=d$
#
#
# $B(0,3,0)$: Substituting
#
#
# $a(0)+b(3)+c(0)=d⟹3b=d$
#
#
# $C(0,0,4)$: Substituting
#
#
# $a(0)+b(0)+c(4)=d⟹4c=d$
#
#
# $Step 3: Relating $a,b,c$
#
#
# From the above equations:
#
#
# $d=2a$ , $d=3b$ , $d=4c$
#
#
# Equating $2a=3b=4c=d$ let $d=12$ (least common multiple of 2, 3, and 4)Then
#
#
# $
# \begin{aligned}
# 2a &= 12 \implies a = 6 \\
# 3b &= 12 \implies b = 4 \\
# 4c &= 12 \implies c = 3
# \end{aligned}$
#
#
# Step 4: Write the Equation of the Plane
#
#
# Substitute $a=6$ , $b=4$ , $c=3 $ into $ax+by+cz=d$ with $d=12$:
#
#
# $6x+4y+3z=12$
#
#
# Final Answer:
#
#
# $6x+4y+3z=12$

# %% [markdown]
# 9)Calculate the angle between the plane
# $x
# +
# y
# +
# z
# =
# 1$
#  and the plane
# $x
# =
# 0$
#  (i.e., the
# y
# z
#  plane)
#
#
#  Step 1: Normal Vectors of the Planes
#
# For the plane $x+y+z=1$ , the normal vector is $
# \vec{n_1} = \langle 1, 1, 1 \rangle$
#
#
# For the plane $x=0$ (the yz-plane), the normal vector is $\vec{n_2} = \langle 1, 0, 0 \rangle$
#
#
# Step 2: Compute the Dot Product
#
#
# The dot product of $\vec{n_1} = \langle 1, 1, 1 \rangle \quad \text{and} \quad \vec{n_2} = \langle 1, 0, 0 \rangle$ is:
#
#
# $\vec{n_1} \cdot \vec{n_2} = (1)(1) + (1)(0) + (1)(0) = 1$
#
#
# Step 3: Compute the Magnitudes of the Vectors
#
#
# The magnitude of $\vec{n_1} = \langle 1, 1, 1 \rangle$ is:
#
#
# $\|\vec{n_1}\| = \sqrt{1^2 + 1^2 + 1^2} = \sqrt{3}$
#
#
# The magnitude of $\vec{n_2} = \langle 1, 0, 0 \rangle$ is:
#
#
# $\|\vec{n_2}\| = \sqrt{1^2 + 0^2 + 0^2} = 1$
#
#
# Step 4: Compute $cosθ$
#
#
# Substitute the values into the formula:
#
#
# $cosθ= $\frac{|\vec{n_1} \cdot \vec{n_2}|}{\|\vec{n_1}\| \|\vec{n_2}\|}
# = \frac{|1|}{\sqrt{3} \cdot 1} = \frac{1}{\sqrt{3}}$
#
#
# Step 5: Find the Angle
#
#
# $\theta = \arccos \left( \frac{1}{\sqrt{3}} \right)$
#
#
# Final Answer:
#
#
# $\theta = \arccos \left( \frac{1}{\sqrt{3}} \right)$

# %% [markdown]
# 10)Find the vector perpendicular to the plane $x+y+z=1$
#
#
# The vector that is perpendicular (normal) to the plane $x+y+z=1$ is simply the normal vector to the plane. The equation of a plane in the form $ax+by+cz=d$ has a normal vector $n=⟨a,b,c⟩$
#
#
# For the plane $x+y+z=1$ , we can rewrite it as:
#
# $1x+1y+1z=1$
#
#
# Thus, the normal vector to the plane is:
#
# $\vec{n} = \langle 1, 1, 1 \rangle$
#
#
# Final Answer:
#
#
# The vector perpendicular to the plane $x+y+z=1$ is:
#
#
# $⟨1,1,1⟩$
