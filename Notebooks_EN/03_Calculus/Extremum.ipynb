# %% [markdown]
# <a href="https://colab.research.google.com/github/D0gi9/Math-2024-25-Winter/blob/main/Extremum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Extremum points in mathematics refer to the maximum and minimum values of a function. These points occur where the function changes direction, which is often at its critical points. Here's a concise explanation:
#
#
# **Critical Points:**
#
# A function $f(x)$ has critical points where its derivative $f'(x)$ equals zero or is undefined.
#
#
# **types of Extremum:**
#
#
# Local Maximum: $f(x)$ is greater than nearby values.
#
# Local Minimum: $f(x)$ is less than nearby values.
#
#
# First Derivative Test:
#
#
# If $f′(x)$ changes from positive to negative at $c$, $f(c)$ is a local maximum.
#
#
# If $f′(x)$ changes from negative to positive at $c$, $f(c)$ is a local minimum.
#
#
#
# **Second Derivative Test:**
#
#
# If $f′′(c)>0$, $f(c)$ is a local minimum.
#
#
# If $f′′(c)<0$, $f(c)$ is a local maximum.
#
#
# **Global Extremum:**
#
#
# Compare all local extrema and boundary values to find the highest (maximum) or lowest (minimum) value on the entire domain.
#
#
# Formulas:
#
#
# Critical points: Solve $f'(x)=0$.
#
#
# Test intervals around critical points for behavior using $f′(x)$ or $f′′(x)$.

# %% [markdown]
# 1)The profit function is $P(u) = -2u^2 + 50u - 300$, where $u$ is the number of units sold. Find the number of units that maximize profit.
#
#
# Step 1: Find the derivative of $P(u)$
#
# The derivative of $P(u) = -2u^2 + 50u - 300$ is:
#
#
#
# $P'(u) = \frac{d}{du}(-2u^2 + 50u - 300) = -4u + 50$
#
#
# Step 2: Set the derivative equal to zero
#
#
# To find the critical points:
#
#
# $P'(u) = 0 \implies -4u + 50 = 0 \implies u = \frac{50}{4} = 12.5$
#
# Step 3: Verify if $u=12.5$ is a maximum
#
#
# he second derivative of $P(u)$ is:
#
#
# $P''(u) = \frac{d}{du}(-4u + 50) = -4$
#
#
# Since $P′′(u)=−4<0$ the profit function is concave downward at $u=12.5$
# confirming a maximum.
#
#
# Step 4: Conclusion
#
#
# The number of units that maximizes profit is:
#
#
# $u=12.5$

# %% [markdown]
# 2)You have 10 meters of string, and you need to use it to enclose the largest possible rectangular. Find the dimensions of the rectangle.
#
#
# Step 1: Define the problem
#
#
# $2x + 2y = 10 \implies x + y = 5$
#
#
# The area of the rectangle is:
#
# $A=x⋅y$
#
#
# Step 2: Express $y$ in terms of $x$
#
#
# From equation (1):
#
#
# $y=5−x$
#
#
# Substitute equation (3) into equation (2):
#
#
# $A = x \cdot (5 - x) = 5x - x^2$
#
#
# Step 3: Maximize the area
#
#
# The area $A(x)=5x−x^2$is a quadratic function. To find the value of $x $ that maximizes $A$, we take the derivative and set it to zero:
#
#
# $\frac{dA}{dx} = 5 - 2x$
#
# Set $\frac{dA}{dx} = 0$:
#
#
# $5 - 2x = 0 \implies x = \frac{5}{2} = 2.5$
#
#
# Step 4: Find $y$
#
#
# Using equation (3):
#
#
# $y=5−x=5−2.5=2.5$
#
#
# Step 5: Verify the result
#
#
# The second derivative of $A$ is:
#
#
# $\frac{d^2A}{dx^2} = -2$
#
#
# which is negative, confirming a maximum.
#
#
# Step 6: Conclusion
#
#
# The dimensions of the rectangle that maximize the area are:
#
#
# $x=2.5$ meters , $y=2.5$ meters
#
#
# This is a square with side lengths of 2.5 meters.

# %% [markdown]
# 3)Find extremum od $f(x)=x^2+3x−5$
#
#
# Step 1: Find the derivative of $f(x)$
#
#
# The derivative of $f(x)$ is:
#
# $f'(x) = \frac{d}{dx}(x^2 + 3x - 5) = 2x + 3$
#
#
# Step 2: Set the derivative equal to zero
#
#
# To find critical points:
#
#
# $f'(x) = 0 \implies 2x + 3 = 0 \implies x = -\frac{3}{2}$
#
#
# Step 3: Verify the nature of the extremum
#
#
# The second derivative of $f(x)$ is:
#
#
# $f''(x) = \frac{d}{dx}(2x + 3) = 2$
#
#
# Since $f′′(x)=2>0$ , the function is concave upward, indicating a local minimum at $x = -\frac{3}{2}$
#
#
# Step 4: Find the function value at the critical point
#
#
# Substitute $x = -\frac{3}{2}$ into $f(x)$
#
#
# $f\left(-\frac{3}{2}\right) = \left(-\frac{3}{2}\right)^2 + 3\left(-\frac{3}{2}\right) - 5$
#
#
# Simplify:
#
# $
# f\left(-\frac{3}{2}\right) = \frac{9}{4} - \frac{9}{2} - 5 = \frac{9}{4} - \frac{18}{4} - \frac{20}{4} = -\frac{29}{4}$
#
#
# Step 5: Conclusion
#
#
# The function $f(x)=x^2+3x−5$ has a local minimum at:
#
#
# $
# x = -\frac{3}{2} , \quad f\left(-\frac{3}{2}\right) = -\frac{29}{4}$

# %% [markdown]
# $4)$ Find extremum of $f(x) =\frac{x^2 + 2x + 1}{x-1}$
#
#
# Step 1: Simplify the function
#
#
# The numerator $x^2+2x+1$ can be factored as:
#
# $
# x^2 + 2x + 1 = (x + 1)^2$
#
#
# Thus:
#
# $f(x) =\frac{(x+1)^2}{x-1}$
#
#
# Step 2: Compute the derivative
#
# Using the quotient rule, the derivative of $f(x) =\frac{(x+1)^2}{x-1}$ is:
#
#
# $
# f'(x) = \frac{(x-1)\cdot\frac{d}{dx}[(x+1)^2] - (x+1)^2\cdot\frac{d}{dx}[x-1]}{(x-1)^2}$
#
#
# Substitute:
#
#
# f'(x) = \frac{(x-1)\cdot 2(x+1) - (x+1)^2 \cdot 1}{(x-1)^2}
#
#
# Simplify the numerator:
#
#
# $
# f'(x) = \frac{2(x+1)(x-1) - (x+1)^2}{(x-1)^2}$
#
#
# Factor out $(x+1)$ from the numerator:
#
#
# $f'(x) = \frac{(x+1)[2(x-1) - (x+1)]}{(x-1)^2}$
#
#
# Simplify the terms in the brackets:
#
#
# $2(x−1)−(x+1)=2x−2−x−1=x−3$
#
#
# Thus:
#
# $
# f'(x) = \frac{(x+1)(x-3)}{(x-1)^2}$
#
#
# Step 3: Critical points
#
#
# The critical points occur when $f'(x)=0$ or $𝑓′(𝑥)$ is undefined:
#
# $f′(x)=0$ when $(x+1)(x−3)=0$ , giving
#
#
# $x=−1$ or $x=3$
#
#
# $f′(x)$ is undefined when (x−1)^2 =0, giving:
#
#
#
# $x=1$
#
#
# So, the critical points are $x=−1$ , $x=3$ and $x=1$
#
#
# Step 4: Determine the nature of each critical point
#
#
# Case 1: $x=−1$
#
# o check the behavior of $f′(x)$ around $x=−1$ observe the sign of $f′(x)$
#
#
# $
# \text{For } x < -1: \\
# (x+1) < 0 \\
# (x-3) < 0 \\
# \text{so } f'(x) > 0$
#
#
# $
# \text{For } x > -1: \\
# (x+1) > 0 \\
# (x-3) < 0 \\
# \text{so } f'(x) < 0$
#
#
# Thus, $x=−1$ is a local maximum.
#
#
# Case 2: $x=3$
#
#
# $
# \text{For } -1 < x < 3: \\
# (x+1) > 0 \\
# (x-3) < 0 \\
# \text{so } f'(x) < 0$
#
#
# $
# \text{For } x > 3: \\
# (x+1) > 0 \\
# (x-3) > 0 \\
# \text{so } f'(x) > 0
# $
#
#
# Thus, $x=3$ is a local minimum.
#
#
# Case 3: $x=1$
#
#
# At $x=1$ , the function is undefined because of a vertical asymptote.
#
#
# Step 5: Function values at extrema
#
#
# At $x=−1:$
#
#
# $f(−1) = \frac{-1-1}{(-1+1)^2} = 0$
#
#
# At $x=3:$
#
# $f(3) = \frac{3-1}{(3+1)^2} = 8$
#
#
# Final Conclusion
#
#
# Local maximum: At $x=−1$ , $f(−1)=0$
#
#
# Local minimum: At $x=3$ , $f(3)=8$
#
#
# Vertical asymptote: At $x=1$ , the function is undefined
