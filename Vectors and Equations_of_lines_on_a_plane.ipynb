# %% [markdown]
# <a href="https://colab.research.google.com/github/D0gi9/Math-2024-25-Winter/blob/main/Vectors%20and%20Equations_of_lines_on_a_plane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VECTORS
#
#
# Vectors and Systems of Linear Equations
#
#
# n the context of solving a system of linear equations using matrices, the coefficient matrix A plays a crucial role. If A is invertible (i.e., its determinant
# det $(𝐴)≠0$, we can solve the system using the inverse matrix method:
#
#
#
# $x = A^{-1}b$
#
#
# Here, $x$ is the solution vector, and $b$ is the right-hand side vector. However, if
# $det(A)=0$, the matrix $A$ is singular, meaning it is not invertible. In such cases, the system may:
#
# 1)Have infinitely many solutions if the equations are dependent.
# 2)Be inconsistent if the equations contradict each other.
#
#
#
# # Basic Vector Operations
#
#
# Addition:
#
#
#
# $\mathbf{a} + \mathbf{b} = (a_1 + b_1, a_2 + b_2, a_3 + b_3)$
#
#
# Subtraction:
#
#
# $\mathbf{a} - \mathbf{b} = (a_1 - b_1, a_2 - b_2, a_3 - b_3)$
#
#
#
# Scalar Multiplication:
#
#
#
# $k\mathbf{a} = (ka_1, ka_2, ka_3)$
#
#
# #Magnitude (Length) of a Vector
#
#
#
# $\|\mathbf{a}\| = \sqrt{a_1^2 + a_2^2 + a_3^2}$
#
#
#
# #Dot Product
#
#
#
# $\mathbf{a} \cdot \mathbf{b} = a_1 b_1 + a_2 b_2 + a_3 b_3$
#
#
#
# Properties:
#
# $a⋅b=0$: Vectors are orthogonal.
#
# $\mathbf{a} \cdot \mathbf{a} = \|\mathbf{a}\|^2$
#
#
# #Cross Product (in 3D)
#
#
# $\mathbf{a} \times \mathbf{b} = \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# a_1 & a_2 & a_3 \\
# b_1 & b_2 & b_3
# \end{vmatrix}$
#
#
#
# This results in a vector perpendicular to both $a$ and $b$.
#
#
# #Angle Between Vectors
#
#
# $\cos\theta = \frac{\mathbf{a} \cdot \mathbf{b}}{\|\mathbf{a}\| \|\mathbf{b}\|}$
#
#
# #Projection of a Vector
#
#
# Projection of $a$ onto $b$
#
#
#
# $\text{proj}_\mathbf{b} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{b}}{\|\mathbf{b}\|^2} \mathbf{b}$
#
#
# #Vector Equation of a Line
#
#
# For a line passing through point $p$ with direction vector $d$:
#
#
#
# $\mathbf{r}(t) = \mathbf{p} + t\mathbf{d}, \quad t \in \mathbb{R}$
#
#
# #Plane Equation
#
#
# For a plane with normal vector $n = (a,b,c)$ and passing through point $p_0 = (x_0,y_0,z_0)$
#
#
# $a(x - x_0) + b(y - y_0) + c(z - z_0) = 0$

# %% [markdown]
# # Vectors I
#
# 1)By what number should vector $a=[3,4]$ be multiplied so that its length is equal to 1?
#
#
# To make the length of the vector $𝑎=[3,4]$ equal to 1, we need to multiply it by the reciprocal of its magnitude. The magnitude of $a$ is given by:
#
#
# $∥a∥$= $\sqrt{3^2 + 4^2}$ = $\sqrt{9+6} = 5
#
# The scaling factor to make the vector's length $1$ is:
#
#
# $k = \frac{1}{\|\mathbf{a}\|} = \frac{1}{5}$
#
#
# Thus, the vector $a$ should be multiplied by $\frac{1}{5}$.
#
#
# 2)Calculate the length of vector $b=[1,1]$ and find the unit vector of this vector.
#
#
# Step 1: Calculate the Length of $b=[1,1]$
#
#
# $∥b∥$ = $\sqrt{b_1^2 + b_2^2}$
#
#
# For $b=[1,1]$:
#
#
# $∥b∥$ = $\sqrt{1^2 + 1^2}$ = $\sqrt{2}$
#
# Step 2: Find the Unit Vector of $b$
#
# $u$ = $\frac{\mathbf{b}}{\|\mathbf{b}\|}$ = $\left[ \frac{1}{\sqrt{2}}, \frac{1}{\sqrt{2}} \right] $
#
# Final Results:
#
# Length of $b$ : ${\sqrt{2}}$
#
#
# Unit vector of $b$: $u = $ $\left[ \frac{1}{\sqrt{2}}, \frac{1}{\sqrt{2}} \right] $
#
#
# 2.1)Plot the vector and the unit vector from the previous exercise.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the vector
vector = np.array([1, 1])

# Calculate the magnitude of the vector
magnitude = np.linalg.norm(vector)

# Calculate the unit vector
unit_vector = vector / magnitude

# Create the plot
plt.figure(figsize=(6, 6))  # Set figure size

# Plot the original vector
plt.arrow(0, 0, vector[0], vector[1], head_width=0.05, head_length=0.1, fc='blue', ec='blue', length_includes_head=True, label='Original Vector')

# Plot the unit vector
plt.arrow(0, 0, unit_vector[0], unit_vector[1], head_width=0.05, head_length=0.1, fc='red', ec='red', length_includes_head=True, label='Unit Vector')

# Set plot limits and labels
plt.xlim([-0.2, 1.2])
plt.ylim([-0.2, 1.2])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Vector and Unit Vector')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# 3)Calculate the length of vector $c=[1,2,3]$ and find the unit vector of this vector.
#
#
# Step 1: Calculate the Length of $c=[1,2,3]$
#
#
# The length (or magnitude) of a vector $c = [c_1,c_2,c_3]$ is given by:
#
#
# $∥c∥$ $=$ $\sqrt{c_1^2 + c_2^2 + c_3^2}$
#
#
# For $c=[1,2,3]$:
#
#
# $∥c∥=$ $\sqrt{1^2 + 2^2 + 3^2}$ $=\sqrt{14}$
#
# Step 2: Find the Unit Vector of $c$
#
# The unit vector $u$ is obtained by dividing each component of $c$ by its length:
#
#
# $u=$ $\frac{\mathbf{c}}{\|\mathbf{c}\|}$ = $\left[ \frac{1}{\sqrt{14}}, \frac{2}{\sqrt{14}}, \frac{3}{\sqrt{14}} \right]$
#
#
# **Final Results:**
#
#
# Length of $c$:$=\sqrt{14}$
#
# Unit vector of $c$: $\frac{\mathbf{c}}{\|\mathbf{c}\|}$ = $\left[ \frac{1}{\sqrt{14}}, \frac{2}{\sqrt{14}}, \frac{3}{\sqrt{14}} \right]$

# %% [markdown]
# 4)Find the Cartesian coordinates of vector $v=[2,3,4]$ in the basis $b_1=[1,0,1],b_2=[0,1,0],b_3=[1,0,−1].$
#
#
# $We want to find scalars $𝛼_1,𝛼_2,𝛼_3α$ such that:
#
#
# $\mathbf{v} = \alpha_1 \mathbf{b}_1 + \alpha_2 \mathbf{b}_2 + \alpha_3 \mathbf{b}_3$
#
#
# This equation becomes:
#
#
#
# $[2,3,4]=$\alpha_1 [1,0,1] + \alpha_2 [0,1,0] + \alpha_3 [1,0,-1]$
#
#
# This leads to the following system of equations:
#
#
# $\alpha_1 (1) + \alpha_2 (0) + \alpha_3 (1) = 2$
#
# $\alpha_1 (0) + \alpha_2 (1) + \alpha_3 (0) = 3$
#
# $\alpha_1 (1) + \alpha_2 (0) + \alpha_3 (-1) = 4$
#
# Simplifying the system:
#
#
# $\alpha_1 + \alpha_3 = 2$
#
# $\alpha_2 = 3$
#
# $\alpha_1 - \alpha_3 = 4$
#
#
# Now, let's solve this system of equations.
#
# $\alpha_1 + \alpha_3 = 2$
#
# $\alpha_1 - \alpha_3 = 4$
#
#
# Add these two equations:
#
# $2\alpha_1 = 6$
#
# $\alpha_1 = 3$
#
#
# Substitute $\alpha_1 = 3$ into $\alpha_1 + \alpha_3 = 2$
#
#
# $3 + \alpha_3 = 2$
#
#
# $\alpha_3 = -1$
#
#
# we have:
#
#
# $\alpha_1 = -3$ , $\alpha_2 = 3$ , $\alpha_3 = -1$
#
#
# Therefore, the Cartesian coordinates of the vector $v=[2,3,4]$ in the new basis
# are:
#
#
#
# $[\alpha_1, \alpha_2, \alpha_3]= [3,3,-1]$

# %% [markdown]
# # Vectors II
#
#
# 1)Perform the addition of vector $[2,1]$ to vector $[−1,1]$. Plot both vectors and their sum on a graph.
#
#
# To perform the addition of the vectors $[2,1]$ and $[−1,1]$, we simply add the corresponding components of the vectors:
#
#
# $[2,1]+[−1,1]=[2+(−1),1+1]=[1,2]$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the vectors
v1 = np.array([2, 1])
v2 = np.array([-1, 1])
v_sum = np.array([1, 2])

# Create the plot
plt.figure(figsize=(6, 6))

# Plot the vectors as arrows
plt.arrow(0, 0, v1[0], v1[1], head_width=0.05, head_length=0.1, fc='blue', ec='blue', length_includes_head=True, label='v1 = [2, 1]')
plt.arrow(0, 0, v2[0], v2[1], head_width=0.05, head_length=0.1, fc='red', ec='red', length_includes_head=True, label='v2 = [-1, 1]')
plt.arrow(0, 0, v_sum[0], v_sum[1], head_width=0.05, head_length=0.1, fc='green', ec='green', length_includes_head=True, label='v1 + v2 = [1, 2]')

# Set plot limits, labels, and title
plt.xlim([-2, 3])
plt.ylim([-1, 3])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Vectors and Their Sum')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# 2)Calculate the area of the triangle spanned by vectors $[2,1]$and $[−1,1]$.
#
#
#
# The area of a triangle spanned by two vectors can be found using the formula:
#
#
# $\text{Area} = \frac{1}{2} |\det(\mathbf{A})|$
#
# where $A$ is a matrix with the vectors as its columns the matrix is:
#
#
# $\mathbf{A} = \begin{bmatrix} 2 & -1 \\ 1 & 1 \end{bmatrix}$
#
#
#
# The area is then:
#
#
# Area = $\frac{1}{2} \det \begin{bmatrix} 2 & -1 \\ 1 & 1 \end{bmatrix}$
#
#
# $det(A)$=$ad−bc$
#
#
# For the given matrix:
#
#
# $\det \begin{bmatrix} 2 & -1 \\ 1 & 1 \end{bmatrix}$ $=(2×1)−(−1×1)=2+1=3$
#
#
# Thus, the area of the triangle is:
#
# Area= $\frac{1}{2} \times |3| = \frac{3}{2}$
#
#
# **Final answer**
#
#
# $\frac{3}{2}$

# %% [markdown]
# 3)Calculate the volume of the parallelepiped spanned by vectors $[2,1]$, $[−1,1]$,and $[1,2]$.
#
# we need to use that formule for  solve this question
#
# $V = |\mathbf{v}_1 \cdot (\mathbf{v}_2 \times \mathbf{v}_3)|$
#
#
# Step 1: Cross product of $v_2$ and $v_3$
#
# The formula for the cross product in 3D is:
#
#
# $\mathbf{v}_2 \times \mathbf{v}_3 = \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# -1 & 1 & 0 \\
# 1 & 2 & 0
# \end{vmatrix}$
#
#
# This determinant can be expanded as:
#
#
# $\mathbf{v}_2 \times \mathbf{v}_3 = \mathbf{i} \begin{vmatrix} 1 & 0 \\ 2 & 0 \end{vmatrix} - \mathbf{j} \begin{vmatrix} -1 & 0 \\ 1 & 0 \end{vmatrix} + \mathbf{k} \begin{vmatrix} -1 & 1 \\ 1 & 2 \end{vmatrix}$
#
#
# ince the third components of both vectors are zero, we only need to calculate the determinant for the $k$ component:
#
# $\mathbf{v}_2 \times \mathbf{v}_3 = \mathbf{k} \begin{vmatrix} -1 & 1 \\ 1 & 2 \end{vmatrix}$
#
#
# Calculating this determinant:
#
#
# $\begin{vmatrix} -1 & 1 \\ 1 & 2 \end{vmatrix} = (-1)(2) - (1)(1) = -2 - 1 = -3$
#
#
# Thus, the cross product is:
#
#
# $\mathbf{v}_2 \times \mathbf{v}_3 = \mathbf{k}(-3) = \begin{bmatrix} 0 \\ 0 \\ -3 \end{bmatrix}$
#
#
# Step 2: Dot product of v$_1$ with the cross product
#
#
# $\mathbf{v}_1 \cdot (\mathbf{v}_2 \times \mathbf{v}_3) = (2)(0) + (1)(0) + (0)(-3) = 0$
#
#
# Step 3: Conclusion
#
#
# Since the dot product is zero, the volume of the parallelepiped is:
#
#
# $V=∣0∣=0$
#
#
# Thus, the volume of the parallelepiped spanned by the vectors $[2,1]$, $[−1,1]$, $[1,2]$ is $0$. This indicates that the three vectors lie in the same plane (they are coplanar), so the parallelepiped does not have a 3D volume.

# %% [markdown]
# 4)Check if vectors $[2,1]$and $[−1,1]$ are perpendicular.
#
# To check if two vectors are perpendicular, we compute their dot product.
#
# $a⋅b=a_1 b_1+a_2 b_2 =0$
#
#
# For the vectors $[2,1]$ and $[−1,1]$, their dot product is:
#
#
# $[2,1]⋅[−1,1]=(2)(−1)+(1)(1)=−2+1=−1$
#
#
# Since the dot product is $−1$ (which is not zero), the vectors $[2,1]$ and $[−1,1]$ are not perpendicular.

# %% [markdown]
# 5)Calculate the angle in degrees between vectors $[4,2,1]$ and $[1,3,2]$
#
#
# To calculate the angle $θ$ between two vectors $𝑎=[𝑎_1,𝑎_2,a_3]$ and $b=[b_1,b_2,b_3$ we use the formula:
#
# $\cos\theta = \frac{\mathbf{a} \cdot \mathbf{b}}{\|\mathbf{a}\| \|\mathbf{b}\|}$
#
#
# $a⋅b$ is the dot product of $a$ and $b$
#
# $∣a∣$ is the magnitude of $a$,
#
# $∣b∣$ is the magnitude of $b$.
#
#
# Step 1: Compute the dot product $a⋅b$
#
#
# $a⋅b=(4)(1)+(2)(3)+(1)(2)=4+6+2=12$
#
#
# Step 2: Compute the magnitudes of $a and 𝑏$
#
#
# The magnitude of $a$ is:
#
# $∣a∣=$ $\sqrt{4^2 + 2^2 + 1^2}$ = $\sqrt{21}$
#
#
# The magnitude of $b$ is:
#
#
# $∣b∣=$ $\sqrt{1^2 + 3^2 + 2^2}$ = $\sqrt{14}$
#
#
# Step 3: Calculate $cosθ$
#
#
# $cosθ=\frac{12}{\sqrt{21} \times \sqrt{14}} = \frac{12}{\sqrt{294}}$
#
#
# Approximating the denominator:
#
# ${\sqrt{294}}$≈17.146
#
# $\cos\theta \approx \frac{12}{\sqrt{294}} \approx 0.700$
#
# Step 4: Calculate the angle $θ$
#
#
# Finally, we find $θ$ by taking the inverse cosine (arccos):
#
#
# $\theta = \arccos(0.700)$
#
#
# Using a calculator:
#
#
# $θ≈45.57^∘$

# %% [markdown]
# 6)For three-dimensional vectors: $a=a_x,a_y,a_z$ , $=b_x,b_y,b_z$ , $c=c_x,c_y,c_z$ prove that the following identity is satisfied:
#
# $\mathbf{a} \times (\mathbf{b} \times \mathbf{c}) = (\mathbf{a} \cdot \mathbf{c})\mathbf{b} - (\mathbf{a} \cdot \mathbf{b})\mathbf{c}$
#
#
# i dont understand this problem $:($ $???$

# %% [markdown]
# #  Vectors III
#
#
# 1)Divide the line segment connecting points $A(−1,2)$ and $B(3,−2)$ in the ratio $1:3$. Illustrate the result on a graph.

# %%
import numpy as np
import matplotlib.pyplot as plt
A = np.array([-1, 2])  # Point A
B = np.array([3, -2])  # Point B
ratio = 1/3  # Ratio 1:3
P = (1 - ratio) * A + ratio * B
plt.figure(figsize=(6, 6))
plt.plot([A[0], B[0]], [A[1], B[1]], marker='o', label='Line Segment AB')
plt.plot(P[0], P[1], marker='o', markersize=8, color='red', label='Dividing Point P')
plt.text(A[0], A[1], 'A', ha='right', va='bottom')
plt.text(B[0], B[1], 'B', ha='left', va='top')
plt.text(P[0], P[1], 'P', ha='left', va='bottom')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Dividing a Line Segment')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 2)Project vector $a=(3,4)$ onto the $OX$ and $OY$ axes. Illustrate the result on a graph.

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([3, 4])
a_proj_x = np.array([a[0], 0])  # Projection onto OX
a_proj_y = np.array([0, a[1]])  # Projection onto OY
plt.figure(figsize=(6, 6))
plt.arrow(0, 0, a[0], a[1], head_width=0.05, head_length=0.1, fc='blue', ec='blue', length_includes_head=True, label='Vector a')
plt.arrow(0, 0, a_proj_x[0], a_proj_x[1], head_width=0.05, head_length=0.1, fc='red', ec='red', length_includes_head=True, label='Projection onto OX')
plt.arrow(0, 0, a_proj_y[0], a_proj_y[1], head_width=0.05, head_length=0.1, fc='green', ec='green', length_includes_head=True, label='Projection onto OY')
plt.xlim([-1, 4])
plt.ylim([-1, 5])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Vector Projection onto Axes')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 3)Project vector $a=(2,3)$ onto vector $b=(1,1)$. Ilustrate the result on a graph.

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([2, 3])
b = np.array([1, 1])

a_proj_b = (np.dot(a, b) / np.dot(b, b)) * b


plt.figure(figsize=(6, 6))
plt.arrow(0, 0, a[0], a[1], head_width=0.05, head_length=0.1, fc='blue', ec='blue', length_includes_head=True, label='Vector a')
plt.arrow(0, 0, b[0], b[1], head_width=0.05, head_length=0.1, fc='green', ec='green', length_includes_head=True, label='Vector b')
plt.arrow(0, 0, a_proj_b[0], a_proj_b[1], head_width=0.05, head_length=0.1, fc='red', ec='red', length_includes_head=True, label='Projection of a onto b')
plt.xlim([-1, 3])
plt.ylim([-1, 4])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Vector Projection')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 4)Project vector $b=(1,1)$ onto vector $a=(2,3)$. Ilustrate the result on a graph.

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([2, 3])
b = np.array([1, 1])

b_proj_a = (np.dot(b, a) / np.dot(a, a)) * a

plt.figure(figsize=(6, 6))
plt.arrow(0, 0, a[0], a[1], head_width=0.05, head_length=0.1, fc='blue', ec='blue', length_includes_head=True, label='Vector a')
plt.arrow(0, 0, b[0], b[1], head_width=0.05, head_length=0.1, fc='green', ec='green', length_includes_head=True, label='Vector b')
plt.arrow(0, 0, b_proj_a[0], b_proj_a[1], head_width=0.05, head_length=0.1, fc='red', ec='red', length_includes_head=True, label='Projection of b onto a')
plt.xlim([-1, 3])
plt.ylim([-1, 4])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Vector Projection')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #Equations of lines on a plane
#
#
# **Slope-Intercept Form:**
#
# $y=mx+c$
#
# $m$ is the slope (gradient) of the line, representing the rate of change of $y$ with respect to $x$.
#
#
# $c$ is the y-intercept, the point where the line crosses the y-axis.
#
# **Point-Slope Form:**
#
#
# $y−y_1=m(x−x_1)$
#
#
# This form uses a known point $(x_1,y_1)$ on the line and the slope $m$.
#
#
# **General Form:**
#
#
# $Ax+By+C=0$
#
# In this form, $A,B,$ and $C$ are constants, and the equation can represent any line in a plane.
#
# $Two-Point Form$
#
# $y−y_1$=$\frac{y_2 - y_1}{x_2 - x_1}$ $(x−x_1​)$ This is used when two points (x_1,y_1) and $(x_2,y_2)$ on the line are known. The slope is calculated using these points.
#
#
# **Important Concepts:**
#
#
# Slope of a Line: The slope $m$ is the ratio of the vertical change to the horizontal change between two points on the line,
#
#
# $m = \frac{y_2 - y_1}{x_2 - x_1}$
#
#
# Perpendicular Lines:Two lines are perpendicular if the product of their slopes is $−1,i.e.,𝑚_1 × 𝑚_2= −1$
#
# Parallel Lines:Two lines are parallel if they have the same slope,m_1=m_2$
#
#
# 1)the line passes through points $A(1,2)$ and $B(3,4)$. Find the equation of the line.
#
#
# To find the equation of the line passing through points $A(1,2)$ and $B(3,4)$, we use the slope-intercept form of a line equation:
#
#
# $y=mx+c$
#
# Step 1: Calculate the slope $(m)$
#
#
# $m = \frac{x_2 - x_1}{y_2 - y_1}$
#
#
# Substitute $A(1,2)$ and $B(3,4)$:
#
# Step 2: Use point-slope form to find the equation
#
#
# The point-slope form of a line is:
#
#
# $y - y_1 = m(x - x_1)$
#
#
# Substitute $m=1$ and point $A(1,2)$:
#
#
# $y - 2 = 1(x - 1)$
#
#
# Simplify:
#
#
# $y−2=x−1$
#
#
# $y=x+1$
#
#
# Final Answer:
#
#
# $y=x+1$

# %% [markdown]
# 2)The line passes through point $A(1,2)$ and is parallel to the line $y=2x+3$. Find the equation of the line.
#
#
# Step 1: Identify the slope of the given line
#
#
# The slope of the line $y=2x+3$ is $m=2$
#
#
# Since the required line is parallel to this line, its slope is also $m=2$.
#
#
# Step 2: Use the point-slope form of the line equation
#
#
# The point-slope form is:
#
#
# $y - y_1 = m(x - x_1)$
#
#
# Substitute $m=2$ and $A(1,2)$:
#
#
# $y−2=2(x−1)$
#
#
# Step 3: Simplify the equation
#
#
# Expand and simplify:
#
#
# $y−2=2x−2$
#
#
# $y=2x$
#
#
# Final Answer:
#
#
# $y=2x$

# %% [markdown]
# 3)The line passes through point $A(1,2)$ and is perpendicular to the line $y=2x+3$
# . Find the equation of the line.
#
#
# Step 1: Identify the slope of the given line
#
#
# The slope of the line $y=2x+3$ is $m=2$.
#
#
# Step 2: Find the slope of the perpendicular line
#
#
# The slope of a line perpendicular to another is the negative reciprocal of the original slope. So, if the slope of the given line is $m=2$, the slope of the perpendicular line is:
#
# $m_{\perp} = -\frac{1}{2}$
#
# Step 3: Use the point-slope form of the line equation
#
# $y−y_1=m(x−x_1)$
#
#
# Substitute $m = -\frac{1}{2}$ and $A(1,2)$:
#
#
# $y - 2 = -\frac{1}{2}(x - 1)$
#
#
# Step 4: Simplify the equation
#
#
# $y - 2 = -\frac{1}{2}x + \frac{1}{2}$
#
#
# $y = -\frac{1}{2}x + \frac{1}{2} + 2$
#
#
# $y = -\frac{1}{2}x + \frac{5}{2}$
#
#
# Final Answer:
#
#
# $y = -\frac{1}{2}x + \frac{5}{2}$

# %% [markdown]
# 4)We have two lines $y=2x+3$ and $y=3x+2$. Find the intersection point of these lines and calculate the angle between them.
#
#
# Step 1: Find the intersection point of the two lines
#
#
# $2x+3=3x+2$
#
#
# Simplify:
#
#
# $3−2=3x−2x$
#
#
# $x=1$
#
#
# Substitute $x=1$ into one of the equations
#
#
# $y=2(1)+3=5$
#
#
# Thus, the intersection point is:
#
#
# $(1,5)$
#
# Step 2: Calculate the angle between the two lines
#
#
# $\tan\theta = \left| \frac{m_2 - m_1}{1 + m_1 m_2} \right|$
#
# Here:
#
# Slope of the first line: $m_1=2$
#
#
# Slope of the second line: $m_2 =3$
#
#
# Substitute into the formula:
#
# $
# \tan\theta = \frac{3 - 2}{1 + 2 \cdot 3}$
#
#
# $
# \tan\theta = \frac{1}{7} $
#
#
# Take the arctangent to find $θ$:
#
#
# $
# \theta = \arctan\left(\frac{1}{7}\right)$
#
#
# Step 3: Final results
#
# Intersection Point: $(1,5)$
#
#
# $
# \theta = \arctan\left(\frac{1}{7}\right) \approx 8.13^{\circ}$

# %% [markdown]
# 5)Write the equation of the line passing through point $A(1,2)$ and parallel to the vector $v=[2,3]$.
#
#
# Parametric Form of the Line:
#
# If a line passes through a point $(𝑥_0,𝑦_0)$ and is parallel to a vector $v=[a,b]$, its parametric equation is:
#
#
#
# $x = x_0 + at$
#
#
# $y = y_0 + bt$
#
#
# Here, $t$ is a parameter.
#
#
# Substitute $A(1,2)$ for $(x_0 ,y_0)$ $and v=[2,3]$ for $(a,b)$:
#
#
# $x=1+2t$
#
#
# $y=2+3t$
#
#
# Eliminate the Parameter
#
#
# To write the equation in Cartesian form, eliminate $t$. Solve for $t$ in the first equation:
#
#
# $t = \frac{x - 1}{2}$
#
#
# Substitute this into the second equation:
#
#
# $y = 2 + 3\left(\frac{x - 1}{2}\right)$
#
# Simplify:
#
#
# $y = 2 + \frac{3(x - 1)}{2}$
#
#
# $y = 2 + \frac{3x - 3}{2}$
#
#
# $y = \frac{3x}{2} - \frac{3}{2} + 2$
#
#
# $y = \frac{3x}{2} + \frac{1}{2}$
#
#
# Final Answer
#
#
#
# $y = \frac{3x}{2} + \frac{1}{2}$

# %% [markdown]
# 6)We have the line $y=2x+3$ Find an example of a line perpendicular and parallel to it.
#
#
# A Line Parallel to $y=2x+3$:
#
#
# Parallel lines have the same slope. The slope of $y=2x+3$ is $m=2$. Therefore, the equation of any parallel line is:
#
#
# $y=2x+c$
#
#
# Here, $c$ is the y-intercept, which can be any value. For example, choose $c=5$:
#
#
# $y=2x+5$
#
#
# A Line Perpendicular to $y=2x+3$:
#
#
# The slope of a line perpendicular to another is the negative reciprocal of the slope. Since the slope of $y=2x+3$ is $m=2$, the slope of a perpendicular line is:
#
#
# $m = -\frac{1}{2}$
#
#
# The equation of a line perpendicular to $y=2x+3$ is:
#
#
# $y = -\frac{1}{2}x + c$
#
#
# Here, $c$ is the y-intercept, which can be any value. For example, choose
# $c=4$:
#
#
# $y = -\frac{1}{2}x + 4$
#
#
# Final Answer:
#
#
# Parallel Line: $y=2x+5$
#
#
# Perpendicular Line:$y = -\frac{1}{2}x + 4$

# %% [markdown]
# 7)We have the line $y=2x+3$ and point $A(1,2)$ Find the distance from point $A$ to the line.
#
#
# The formula to calculate the distance $d$ from a point $A(x 1 ,y 1​ )$ to a line in the form $ax+by+c=0$ is:
#
#
# $d = \frac{|ax_1 + by_1 + c|}{\sqrt{a^2 + b^2}}$
#
#
# Step 1: Rewrite the line equation
#
#
# The given line is $y=2x+3$ Rewrite it in standard form $ax+by+c=0$:
#
#
# $−2x+y−3=0$
#
#
# Here:
#
# $a=−2$
#
# $b=1$
#
# $c=−3$
#
#
# Step 2: Substitute the point $A(1,2)$
#
#
# The point A(1,2) has $x_1​ =1$ and $𝑦_1=2$ Substitute into the formula:
#
#
# $
# d = \frac{|(-2)(1) + (1)(2) - 3|}{\sqrt{(-2)^2 + 1^2}}$
#
#
# $
# d = \frac{|-3|}{\sqrt{5}}$
#
#
# $d = \frac{3}{\sqrt{5}}$
#
#
# Final Answer:
#
#
# $d = \frac{3}{\sqrt{5}}$

# %% [markdown]
# 8)The line intersects the coordinate axes at points $A(2,0)$ and $B(0,3)$ Find the equation of the line.
#
# Step 1: Use the two-point form of the equation of a line
#
#
# The two-point form of a line passing through two points $(𝑥_1,y_1) and (𝑥_2,y_2)$ is:
#
#
# $y - y_1 = \frac{y_2 - y_1}{x_2 - x_1}(x - x_1)$
#
#
# Here, $(x_1, y_1) = (2, 0) \quad \text{and} \quad (x_2, y_2) = (0, 3)$
#
#
# Step 2: Calculate the slope $(m)$
#
#
# The slope is:
#
# $m = \frac{y_2 - y_1}{x_2 - x_1}$ = $\frac{3 - 0}{0 - 2}$ = $-\frac{3}{2}$
#
#
# Step 3: Substitute into the equation
#
#
# Using the point $(2,0)$ and $𝑚=-\frac{3}{2}$
#
#
# $y - 0 = -\frac{3}{2}(x - 2)$
#
#
# Simplify:
#
#
# $y = -\frac{2}{3}x + 3$
#
#
# Final Answer:
#
# The equation of the line is:
#
# $
# y = -\frac{3}{2}x + 3$

# %% [markdown]
# 9)Calculate the angle between the line $y=x+3$ and the $O_x$ axis.
#
#
# Step 1: Slope and angle relationship
#
#
# The slope of the line $y=mx+c$ is $m$, and the angle $θ$ between the line and the positive x-axis is given by:
#
#
# $θ=arctan(m)$
#
#
# For the line $y=x+3$, the slope $m=1$.
#
#
# Step 2: Compute the angle
#
#
# Substitute $m=1$ into the formula:
#
# $θ=arctan(1)$
#
#
# $arctan(1)=45^∘$
#
#
# Final Answer:
#
#
# $θ=45^∘$

# %% [markdown]
# 10)Provide a vector perpendicular to the line $x+y+1=0$.
#
# Step 1: Perpendicular vector
#
# The direction vector of a line in the form $ax+by+c=0$ is $v=[a,b]$, and a vector perpendicular to the line is a vector parallel to the normal vector to the line.
#
# Since the normal vector to the line is $n=[a,b]$, we can directly take:
#
#
# $n=[1,1]$
#
#
# Final Answer:
#
# A vector perpendicular to the line $x+y+1=0$ is $n=[1,1]$.
