# %% [markdown]
# <a href="https://colab.research.google.com/github/D0gi9/Math-2024-25-Winter/blob/main/Differential_Equations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Differential Equations Overview**
#
#
# A differential equation (DE) is an equation that involves an unknown function and its derivatives. It can be classified as:
#
#
# Types of Differential Equations
#
# Ordinary Differential Equations (ODEs): Involves derivatives with respect to one variable.
#
#
# $F(x, y, y', y'', \dots, y^{(n)}) = 0$
#
# Partial Differential Equations (PDEs): Involves partial derivatives with respect to multiple variables.
#
#
# $F(x, y, u, u_x, u_y, u_{xx}, u_{xy}, \dots) = 0$
#
#
# Order: Highest derivative in the equation.
#
# Degree: Power of the highest derivative (if polynomial).
#
#
# **Solutions & Methods**
#
#
# Separable Equations:
#
# $\frac{dx}{dy} = g(x)h(y)$ $⇒$ $\int \frac{1}{h(y)} dy = \int g(x) dx$
#
#
# Linear First-Order ODE:
#
#
# $\frac{dy}{dx} + P(x)y = Q(x)$
#
#
# Solution:
#
# $ye^{\int P(x) dx} = \int Q(x)e^{\int P(x) dx} dx + C$
#
#
# Homogeneous & Non-Homogeneous Equations
#
#
# $a_n y^{(n)} + a_{n-1} y^{(n-1)} + \dots + a_1 y' + a_0 y = f(x)$
#
#
# If $f(x)=0$, it's homogeneous, otherwise non-homogeneous.
#
#
#  Applications
#
#
#  Newton’s Law of Cooling
#
#  Population Growth (Logistic Equation)
#
#
#  $\frac{dP}{dt} = rP(1 - \frac{P}{K})$
#
#
#  Electrical Circuits (RLC Circuits)
#
#
#  $L \frac{d^2 q}{dt^2} + R \frac{dq}{dt} + \frac{q}{C} = 0$
#
#
# # EXAMPLES

# %% [markdown]
# Solve the following first-order ordinary differential equations:
#
#
# $y'(x) = y(x)$
#
#
# $y'(x) = \frac{1}{2y(x)}$
#
#
# **1st Equation:**
#
#
# This is a separable differential equation:
#
#
# $$\frac{dy}{dx} = y(x)$$
#
#
# Rearrange the equation:
#
#
# $$\frac{dy}{y} = dx$$
#
#
# Integrate both sides:
#
# $$∫\frac{dy}{y} = ∫ dx$$
#
#
# $$ln∣y∣=x+C$$
#
#
# Solve for $y(x)$:
#
#
# $$y(x)=Ce^x$$
#
#
# where $C$ is an arbitrary constant.

# %% [markdown]
# **2nd Equation:**
#
#
# Rewrite the equation in differential form:
#
#
# $$2ydy=dx$$
#
#
# Integrate both sides:
#
#
# $$∫2ydy=∫dx$$
#
#
# $$y^2=x+C$$
#
#
# Solve for $y(x)$:
#
#
# $$y(x)=±\sqrt{x + C}$$
#
#
# where $C$ is an arbitrary constant.
#
#
# #Final Answers
#
#
# $$y(x)=Ce^x$$
#
#
# $$y(x)=±\sqrt{x + C}$$

# %% [markdown]
# Solve the first-order ordinary differential equations using the method of separation of variables for
# $x$ and $y=y(x)$:
#
#
# $\frac{dy}{dx}=\frac{x}{y}$
#
#
# $\frac{dy}{dx}=\frac{y}{x}$
#
#
# $\frac{dy}{dx}=xy$
#
#
# **1st Equation:**
#
#
# Rearrange to separate variables:
#
#
# $$ydy=xdx$$
#
#
# Integrate both sides:
#
# $$∫ydy=∫xdx$$
#
#
# $$\frac{y^2}{2}=\frac{x^2}{2}+C$$
#
#
# Solve for $y(x)$:
#
#
# $$y^2=x^2+C′$$
#
#
# $$y=±\sqrt{x^2 + C′}$$
#
#
# where $𝐶′=2𝐶$ is an arbitrary constant.
#
#
# 2nd Equation:
#
# Rearrange:
#
# $\frac{dy}{y}=\frac{dx}{x}$
#
#
# Integrate both sides:
#
#
# $$∫\frac{dy}{y} = ∫\frac{dx}{x}$$
#
#
# $$ln∣y∣=ln∣x∣+C$$
#
#
# Solve for $y(x)$:
#
#
# $y=Cx$
#
#
# where $C = e^C$ is an arbitrary constant.
#
#
# 3rd Equation:
#
#
# Rearrange:
#
#
# $$\frac{dy}{y}=xdx$$
#
# Integrate both sides:
#
# $$∫\frac{dy}{y}=xdx$$
#
#
# $$ln∣y∣=\frac{x^2}{2} + C$$
#
#
# Solve for $y(x)$:
#
#
# $$y=Ce^{x^2/2}$$
#
#
# where $𝐶=𝑒^𝐶$ is an arbitrary constant.
#
#
# #Final Answers:
#
# $$y=±\sqrt{x^2 + C′}$$
#
#
# $$y=Cx$$
#
#
# $$y=Ce^{x^2/2}$$

# %% [markdown]
# Solve the second-order ordinary differential equations:
#
# $y″(x)+y′(x)=0$ with boundary conditions $y(0)=2$ and $y′(0)=−1$
#
#
# $y″(x)−y(x)=0$, with boundary conditions $y(0)=2$ and $y′(0)=0$
#
#
# $\frac{d^2y(x)}{dx^2} = -\omega^2y(x)$

# %% [markdown]
# **1st equation**
#
#
# Step 1: Find the general solution
#
# The characteristic equation of the ODE is:
#
# $$r^2+r=0$$
#
# Factoring,
#
# $r(r+1)=0$
#
#
# Thus, the roots are $𝑟=0$ and $r=−1$, leading to the general solution:
#
#
# $$y(x)=C_1 +C_2​e^{−x}$$
#
#
# Step 2: Apply boundary conditions
#
# Condition y(0)=2:
#
# $$C_1 + C_2 e^0 = 2 \implies C_1 + C_2 = 2$$
#
#
# Condition $y′(0)=−1$:
#
# $$y'(x) = -C_2 e^{-x}$$
#
# At $x=0$:
#
# $$-C_2 e^0 = -1 \implies -C_2 = -1 \implies C_2 = 1$$
#
# Substituting $C_2=1$ into the first equation:
#
# $$C_1+1=2⇒C_1​=1$$
#
#
# **Final Solution:**
#
#
# $$y(x)=1+e^{−x}$$

# %% [markdown]
# 2nd equation:
#
# Step 1: Find the general solution
#
# The characteristic equation is:
#
# $$r^2−1=0$$
#
# Solving for $r$,
#
# $$r=±1$$
#
#
# Thus, the general solution is:
#
# $$y(x) = C_1 e^x + C_2 e^{-x}$$
#
# Step 2: Apply boundary conditions
#
# Condition $𝑦(0)=2$:
#
# $$C_1 e^0 + C_2 e^0 = 2 \implies C_1 + C_2 = 2$$
#
# Condition $y′(0)=0:$
#
# $$y'(x) = C_1 e^x - C_2 e^{-x}$$
#
#
# At $x=0:$
#
# $$C_1 e^0 - C_2 e^0 = 0 \implies C_1 - C_2 = 0$$
#
#
# So, $𝐶_1=𝐶_2$
#
#
# Substituting into the first equation:
#
# $$C_1 + C_1 = 2 \implies 2C_1 = 2 \implies C_1 = 1, C_2 = 1$$
#
# **Final Solution:**
#
# $$y(x) = e^x + e^{-x} = 2\cosh(x)$$

# %% [markdown]
# 3rd equation:
#
#
# Step 1: Find the general solution
#
# $$r^2+ω^2=0$$
#
#
# Solving for $r$,
#
# $$r=±iω$$
#
# Thus, the general solution is:
#
#
# $$y(x) = C_1 \cos(\omega x) + C_2 \sin(\omega x)$$
#
#
# This is the general solution of the simple harmonic oscillator equation.
#
#
# Step 2: Apply Boundary Conditions
#
# If boundary conditions are provided, we substitute them to solve for $C_1$ and $C_2$. Otherwise, this remains the general solution.

# %% [markdown]
# Check if the function $ψ(t,x)=Acos(ωt+kx)$ is a solution of the second-order partial differential equation (the so-called "wave equation"), where
#
# $v = \frac{\omega}{k}$ = $\frac{2\pi/T}{2\pi/\lambda}$
#
#
# $$\frac{\partial^2 \psi(t, x)}{\partial t^2} - v^2 \frac{\partial^2 \psi(t, x)}{\partial x^2} = 0$$
#
#
#
# Step 1: Compute $\frac{\partial^2 \psi}{\partial t^2}$
#
#
# First, we take the first derivative with respect to $t$:
#
#
# $$\frac{\partial \psi}{\partial t} = -A\omega \sin(\omega t + kx)$$
#
#
# Taking the second derivative:
#
# $$\frac{\partial^2 \psi}{\partial t^2} = -A\omega^2 \cos(\omega t + kx)$$
#
# Step 2: Compute $\frac{\partial^2 \psi}{\partial x^2}$
#
# First, we take the first derivative with respect to $x$:
#
# $$\frac{\partial \psi}{\partial x} = -Ak \sin(\omega t + kx)$$
#
# Taking the second derivative:
#
# $$\frac{\partial^2 \psi}{\partial x^2} = -Ak^2 \cos(\omega t + kx)$$
#
# Step 3: Check the Wave Equation
#
# Substituting these derivatives into the wave equation:
#
# $$(-A\omega^2 \cos(\omega t + kx)) - v^2 (-Ak^2 \cos(\omega t + kx)) = 0$$
#
#
# Simplifying:
#
# $$-A\omega^2 \cos(\omega t + kx) + v^2 Ak^2 \cos(\omega t + kx) = 0$$
#
# Factor out $Acos(ωt+kx)$
#
# $$A\cos(\omega t + kx)(-\omega^2 + v^2 k^2) = 0$$
#
#
# Since $Acos(ωt+kx)$ is not identically zero, we require:
#
# $$-\omega^2 + v^2 k^2 = 0$$
#
#
# Rearranging:
#
# $$\omega^2 = v^2 k^2$$
#
# Using $w=\frac{w}{k}$, we substitute:
#
#
# $$\omega^2 = (\frac{\omega}{k})^2 k^2 = \omega^2$$
#
# Since this holds true, the function $\psi(t,x) = A\cos(\omega t + kx)$ is indeed a solution of the wave equation.
#
# **final answer**
#
# $\psi(t,x) = A\cos(\omega t + kx)$
