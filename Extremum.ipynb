# %% [markdown]
# <a href="https://colab.research.google.com/github/D0gi9/Math-2024-25-Winter/blob/main/Extremum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Extremum**

# %% [markdown]
# The profit function is $P(u)=−2u^2+50u−300$ , where $u$ is the number of units sold. Find the number of units that maximize profit.
#
#
# step 1: Identify the critical points
#
#
# $P'(u) = \frac{d}{du}(-2u^2 + 50u - 300) = -4u + 50$
#
# Set the derivative equal to zero to find the critical points:
#
#
# $−4u+50=0$
#
#
# $u = \frac{4}{50} = 12.5$
#
#
# Step 2: Verify the type of critical point
#
#
# $P ′′(u) = \frac{d}{du}(-4u + 50) = -4$
#
#
# Step 3: Conclusion
#
# The number of units that maximizes the profit is:
#
# 12.5 units
#
#
# ​

# %% [markdown]
# You have 10 meters of string, and you need to use it to enclose the largest possible rectangular. Find the dimensions of the rectangle.
#
# Step 1: Express the perimeter
#
#
# $P=2L+2W$
#
#
# where $L$ is the length and $W$ is the width of the rectangle. Given
# $P=10$, we have:
#
#
# $2L+2W=10$
#
# $L+W=5$
#
#
# Step 2: Express the area
#
# The area $A$ of the rectangle is:
#
# $A=L×W$
#
#
# From equation $(1)$, solve for $W$ in terms of $L$:
#
#
# $W=5−L$
#
# Substitute equation (2) into the area formula:
#
#
# $A=L×(5−L)$
#
#
# $A=5L−L^2$
#
#
# Step 3: Maximize the area
#
# The function $A=5L−L^2$is a quadratic equation. To find the value of
# $L$ that maximizes the area, take the derivative and set it equal to zero:
#
#
# $\frac{dL}{dA} = 5 - 2L$
#
#
# $5−2L=0$
#
#
# $L=2.5$
#
#
# From equation (2):
#
# $W=5−2.5=2.5$
#
#
# Step 4: Verify it’s a maximum
#
#
# The second derivative of A is:
#
#
# $\frac{d^2L}{dA^2} = -2$
#
# Since $\frac{d^2L}{dA^2} < 0$ the function $A$ has a maximum at $L=2.5$
#
#
# Step 5: Conclusion
#
# The rectangle with the largest area is a square with dimensions:
#
# $$2.5m×2.5m$$
# ​

# %% [markdown]
# Find extremum of $f(x)=x^2+3x−5$
#
# Step 1: Find the first derivative
#
#
#
# $$f'(x) = \frac{d}{dx}(x^2 + 3x - 5) = 2x + 3$$
#
#
# Step 2: Find the critical points
#
# $$2x+3=0$$
#
# $$2x=−3$$
#
#
# $$x = -\frac{3}{2}$$
#
#
# So $x = -\frac{3}{2}$ is a critical point.
#
#
# Step 3: Use the second derivative test
#
# To determine whether this critical point is a maximum or minimum, compute the second derivative:
#
#
#
# $$f''(x) = \frac{d}{dx}(2x + 3) = 2$$
#
#
# Since $f′′(x)=2>0$ , the function is concave up at $x = -\frac{3}{2}$ meaning the critical point corresponds to a local minimum.
#
#
# Step 4: Find the value of the function at the critical point
#
#
# $$f(-\frac{3}{2}) = (-\frac{3}{2})^2 + 3(-\frac{3}{2}) - 5$$
#
#
#
# $$f(-\frac{3}{2}) = \frac{9}{4} - \frac{9}{2} - 5$$
#
#
#
# $$f(-\frac{3}{2}) = \frac{9}{4} - \frac{18}{4} - \frac{20}{4}$$
#
#
#
# $$f(-\frac{3}{2}) = -\frac{29}{4}$$
#
#
# Step 5: Conclusion
#
#
# The function $𝑓(𝑥)=𝑥^2+3𝑥−5$ has a local minimum at $x = -\frac{3}{2}$ with a minimum value of:
#
#
# $$-\frac{29}{4}$$

# %% [markdown]
# Find extremum of $f(x) = \frac{x^2 + 2x + 1}{x - 1}$
#
# Step 1: Simplify the function
#
# $$
# f(x) = \frac{(x+1)^2}{x-1}$$
#
# Step 2: Find the derivative
#
#
# $$
# f'(x) = \frac{ vu' - uv'}{v^2}$$
#
#
# Compute $𝑢′$ and $𝑣′$
#
# $u′=2(x+1)  ,  v′=1$
#
#
# Substitute these into the formula:
#
#
# $
# f'(x) = \frac{(x-1)\cdot 2(x+1) - (x+1)^2 \cdot 1}{(x-1)^2}$
#
# Simplify the numerator:
#
# $$
# (x-1) \cdot 2(x+1) = 2(x^2 + x - 1) , (x+1)^2=x^2+2x+1$$
#
#
# Thus
#
# $$
# f'(x) = \frac{2(x^2 + x - 1) - (x^2 + 2x + 1)}{(x-1)^2}$$
#
#
# Simplify further:
#
# $$
# f'(x) = \frac{2x^2 + 2x - 2 - x^2 - 2x - 1}{(x-1)^2} =
# \frac{x^2 - 3}{(x-1)^2}$$
#
# Step 3: Set $f′(x)=0$
#
# The derivative is zero when the numerator is zero:
#
# $$x^2−3=0$$
#
# Solve for $x$:
#
# $$x=±3$$
#
#
# Step 4: Verify the critical points
#
# To confirm whether these are minima, maxima, or points of inflection, consider the second derivative test or analyze the sign of $f′(x)$ around these points.
#
#
# Second derivative test:
#
#
# Compute $f′′(x)$ Alternatively, analyze $f′(x)$:
#
#
# $$
# f'(x) = \frac{x^2 - 3}{(x-1)^2}$$
#
#
# Check the sign of $f′(x)$:
#
# $
# \text{For } x < -\sqrt{3}, \quad f'(x) < 0$
#
# $
# \text{For } -\sqrt{3} < x < \sqrt{3}, \quad f'(x) > 0$
#
# $
# \text{For } x > \sqrt{3}, \quad f'(x) < 0$
#
# Thus:
#
# $x = -\sqrt{3}$ is a local minimum.
#
# $x=\sqrt{3}$ is a local maximum.
#
#
# Step 5: Check the behavior near $x=1$
#
# The function $f(x)$ is undefined at $x=1$ due to a vertical asymptote.
#
#
# Final Answer:
#
# **Local minimum:**
#
# $$x = -\sqrt{3}$$
#
#
# **Local maximum:**
#
# $$x=\sqrt{3}$$
